# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
df=pd.read_csv('TFG_OFICIAL.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17919 entries, 0 to 17918
# Data columns (total 45 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Case_number                     17919 non-null  object
#  1   District_code                   17919 non-null  int64
#  2   District_name                   17919 non-null  object
#  3   Neighborhood_code               17919 non-null  int64
#  4   Neighborhood_name               17919 non-null  object
#  5   Street_code                     17919 non-null  int64
#  6   Street_name                     17919 non-null  object
#  7   Postal_number                   17919 non-null  object
#  8   Week_day                        17919 non-null  object
#  9   Year                            17919 non-null  int64
#  10  Month                           17919 non-null  int64
#  11  Month_name                      17919 non-null  object
#  12  Day_month                       17919 non-null  int64
#  13  Shift                           17919 non-null  object
#  14  Time                            17919 non-null  int64
#  15  Pedestrian_cause                17919 non-null  object
#  16  Type_of_vehicle                 17919 non-null  object
#  17  Sex                             17919 non-null  object
#  18  Age                             17919 non-null  object
#  19  Person_type                     17919 non-null  object
#  20  Pedestrian_collision_place      17919 non-null  object
#  21  Pedestrian_displacement_motive  17919 non-null  object
#  22  Driver_displacement_motive      17919 non-null  object
#  23  Injury_severity                 17919 non-null  object
#  24  Coordinate_UTM_X_ED50           17919 non-null  float64
#  25  Coordinate_UTM_Y_ED50           17919 non-null  float64
#  26  Longitude                       17797 non-null  object
#  27  Latitude                        17797 non-null  object
#  28  Day                             17919 non-null  object
#  29  Holiday                         17919 non-null  object
#  30  Time_segment                    17919 non-null  object
#  31  Vacation_day                    17919 non-null  bool
#  32  Numero_expedient_count          17919 non-null  int64
#  33  Number of victims               17919 non-null  int64
#  34  Slightly injured                17919 non-null  int64
#  35  Severely injured                17919 non-null  int64
#  36  Weekend Exists                  17919 non-null  bool
#  37  Season                          17919 non-null  object
#  38  Density                         17919 non-null  int64
#  39  TM                              17919 non-null  float64
#  40  HRM                             17919 non-null  int64
#  41  PM                              17919 non-null  float64
#  42  PPT                             17919 non-null  float64
#  43  RS24h                           17919 non-null  float64
#  44  VVM10                           17919 non-null  float64
# dtypes: bool(2), float64(7), int64(13), object(23)
# memory usage: 5.9+ MB

# %%
df.drop('District_code', axis=1, inplace=True)
df.drop('Neighborhood_code', axis=1, inplace=True)
df.drop('Street_code', axis=1, inplace=True)
df.drop('Neighborhood_name', axis=1, inplace=True)
df.drop('Street_name', axis=1, inplace=True)
df.drop('Postal_number', axis=1, inplace=True)
df.drop('Month_name', axis=1, inplace=True)
df.drop('Shift', axis=1, inplace=True)
df.drop('Pedestrian_cause', axis=1, inplace=True)
df.drop('Pedestrian_collision_place', axis=1, inplace=True)
df.drop('Pedestrian_displacement_motive', axis=1, inplace=True)
df.drop('Driver_displacement_motive', axis=1, inplace=True)
df.drop('Latitude', axis=1, inplace=True)
df.drop('Longitude', axis=1, inplace=True)
df.drop('Coordinate_UTM_X_ED50 ', axis=1, inplace=True)
df.drop('Coordinate_UTM_Y_ED50', axis=1, inplace=True)

# %%
df.drop('Time_segment', axis=1, inplace=True)

# %%
import pandas as pd

# Supongamos que tu DataFrame se llama 'df' y la columna con las horas es 'Time'
# Crear una función que asigna el segmento de tiempo según las condiciones dadas
def assign_time_segment(time):
    if 6 <= time < 12:
        return '6-12'
    elif 12 <= time < 18:
        return '12-18'
    elif 18 <= time <= 23:
        return '18-23'
    else:
        return '0-6'

# Aplicar la función a la columna 'Time' para crear la nueva columna 'Time_segment'
df['Time_segment'] = df['Time'].apply(assign_time_segment)

# %%
df
# Out:
#            Case_number        District_name  Week_day  Year  Month  Day_month  \
# 0      2021S000001                Les Corts    Friday  2021      1          1
# 1      2021S000001                Les Corts    Friday  2021      1          1
# 2      2021S000002                 Eixample    Friday  2021      1          1
# 3      2021S000002                 Eixample    Friday  2021      1          1
# 4      2021S000002                 Eixample    Friday  2021      1          1
# ...                ...                  ...       ...   ...    ...        ...
# 17914  2022S008011               Nou Barris  Saturday  2022     12         31
# 17915  2022S008007               Nou Barris  Saturday  2022     12         31
# 17916  2022S008007               Nou Barris  Saturday  2022     12         31
# 17917  2022S008009      Sarrià-Sant Gervasi  Saturday  2022     12         31
# 17918  2022S008009      Sarrià-Sant Gervasi  Saturday  2022     12         31
#
#        Time Type_of_vehicle    Sex Age  ... Weekend Exists  Season Density  \
# 0         0      Motorcycle    Man  24  ...           True  Winter       1
# 1         0         Tourism    Man  24  ...           True  Winter       1
# 2        12         Tourism  Woman  49  ...           True  Winter       1
# 3        12      Ciclomotor    Man  50  ...           True  Winter       1
# 4        12         Tourism    Man  21  ...           True  Winter       1
# ...     ...             ...    ...  ..  ...            ...     ...     ...
# 17914    18         Tourism  Woman  43  ...          False  Winter       1
# 17915    21            Taxi  Woman  22  ...          False  Winter       1
# 17916    21            Taxi  Woman  24  ...          False  Winter       1
# 17917    21         Tourism  Woman  27  ...          False  Winter       1
# 17918    21         Tourism    Man  55  ...          False  Winter       1
#
#          TM  HRM      PM  PPT  RS24h  VVM10  Time_segment
# 0       8.9   61  1001.0  0.1    1.5    1.9           0-6
# 1       8.9   61  1001.0  0.1    1.5    1.9           0-6
# 2       8.9   61  1001.0  0.1    1.5    1.9         12-18
# 3       8.9   61  1001.0  0.1    1.5    1.9         12-18
# 4       8.9   61  1001.0  0.1    1.5    1.9         12-18
# ...     ...  ...     ...  ...    ...    ...           ...
# 17914  17.2   57  1020.7  0.0    8.7    1.9         18-23
# 17915  17.2   57  1020.7  0.0    8.7    1.9         18-23
# 17916  17.2   57  1020.7  0.0    8.7    1.9         18-23
# 17917  17.2   57  1020.7  0.0    8.7    1.9         18-23
# 17918  17.2   57  1020.7  0.0    8.7    1.9         18-23
#
# [17919 rows x 29 columns]

# %%
df = df[df['Injury_severity'] != 'Natural Death']

# %%
mapping = {'Slight': 0, 'Slight Assistance': 1, 'Hospitalized': 2, 'Severe': 3, 'Dead': 4}
df['Injury_severity'] = df['Injury_severity'].map(mapping)
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
import pandas as pd


# Identificar los índices de las filas con los valores máximos en 'Injury_severity' dentro de cada grupo de 'Case_number'
max_injury_indices = df.groupby('Case_number')['Injury_severity'].idxmax()

# Seleccionar las filas deseadas usando los índices identificados
df_selected = df.loc[max_injury_indices]

# %%
df=df_selected

# %%
df
# Out:
#            Case_number District_name  Week_day  Year  Month  Day_month  Time  \
# 0      2021S000001         Les Corts    Friday  2021      1          1     0
# 2      2021S000002          Eixample    Friday  2021      1          1    12
# 7      2021S000003       Sant Andreu    Friday  2021      1          1    18
# 10     2021S000004          Eixample    Friday  2021      1          1    20
# 6      2021S000005            Gràcia    Friday  2021      1          1    12
# ...                ...           ...       ...   ...    ...        ...   ...
# 17914  2022S008011        Nou Barris  Saturday  2022     12         31    18
# 17308  2022S008012            Gràcia   Tuesday  2022     12          6    10
# 17378  2022S008013          Eixample  Saturday  2022     12         10     1
# 17912  2023S000004            Gràcia  Saturday  2022     12         31    15
# 17599  2023S000550          Eixample    Monday  2022     12         19     8
#
#       Type_of_vehicle    Sex Age  ... Weekend Exists  Season Density    TM  \
# 0          Motorcycle    Man  24  ...           True  Winter       1   8.9
# 2             Tourism  Woman  49  ...           True  Winter       1   8.9
# 7             Tourism  Woman  46  ...           True  Winter       1   8.9
# 10            Tourism  Woman  58  ...           True  Winter       1   8.9
# 6          Motorcycle    Man  27  ...           True  Winter       1   8.9
# ...               ...    ...  ..  ...            ...     ...     ...   ...
# 17914         Tourism  Woman  43  ...          False  Winter       1  17.2
# 17308      Motorcycle  Woman  48  ...          False  Winter       1  12.8
# 17378      Motorcycle    Man  27  ...          False  Winter       1  12.4
# 17912         Bicycle    Man  48  ...          False  Winter       1  17.2
# 17599         Tourism  Woman  51  ...          False  Winter       2  14.2
#
#        HRM      PM  PPT  RS24h  VVM10  Time_segment
# 0       61  1001.0  0.1    1.5    1.9           0-6
# 2       61  1001.0  0.1    1.5    1.9         12-18
# 7       61  1001.0  0.1    1.5    1.9         18-23
# 10      61  1001.0  0.1    1.5    1.9         18-23
# 6       61  1001.0  0.1    1.5    1.9         12-18
# ...    ...     ...  ...    ...    ...           ...
# 17914   57  1020.7  0.0    8.7    1.9         18-23
# 17308   74  1011.7  0.0    7.0    0.9          6-12
# 17378   56  1001.0  0.3    7.4    2.6           0-6
# 17912   57  1020.7  0.0    8.7    1.9         12-18
# 17599   86  1024.3  0.0    7.2    1.1          6-12
#
# [14206 rows x 29 columns]

# %%
df.to_csv('TFG_classificat_4.csv',index=False)

# %%
import pandas as pd

# Suponiendo que tu DataFrame se llama 'df'
# Crear la columna 'Number of victims by time segment'
df['Number of victims by time segment'] = df.groupby(['Day', 'Time_segment'])['Numero_expedient_count'].transform('sum')

# Verificar los cambios
print(df[['Day', 'Time_segment', 'Numero_expedient_count', 'Number of victims by time segment']].head())
# Out:
#            Day Time_segment  Numero_expedient_count  \
# 0   01/01/2021          0-6                       2
# 2   01/01/2021        12-18                       4
# 7   01/01/2021        18-23                       3
# 10  01/01/2021        18-23                       4
# 6   01/01/2021        12-18                       1
#
#     Number of victims by time segment
# 0                                   2
# 2                                   5
# 7                                   7
# 10                                  7
# 6                                   5

# %%
df
# Out:
#            Case_number District_name  Week_day  Year  Month  Day_month  Time  \
# 0      2021S000001         Les Corts    Friday  2021      1          1     0
# 2      2021S000002          Eixample    Friday  2021      1          1    12
# 7      2021S000003       Sant Andreu    Friday  2021      1          1    18
# 10     2021S000004          Eixample    Friday  2021      1          1    20
# 6      2021S000005            Gràcia    Friday  2021      1          1    12
# ...                ...           ...       ...   ...    ...        ...   ...
# 17914  2022S008011        Nou Barris  Saturday  2022     12         31    18
# 17308  2022S008012            Gràcia   Tuesday  2022     12          6    10
# 17378  2022S008013          Eixample  Saturday  2022     12         10     1
# 17912  2023S000004            Gràcia  Saturday  2022     12         31    15
# 17599  2023S000550          Eixample    Monday  2022     12         19     8
#
#       Type_of_vehicle    Sex Age  ...  Season  Density    TM HRM      PM  PPT  \
# 0          Motorcycle    Man  24  ...  Winter        1   8.9  61  1001.0  0.1
# 2             Tourism  Woman  49  ...  Winter        1   8.9  61  1001.0  0.1
# 7             Tourism  Woman  46  ...  Winter        1   8.9  61  1001.0  0.1
# 10            Tourism  Woman  58  ...  Winter        1   8.9  61  1001.0  0.1
# 6          Motorcycle    Man  27  ...  Winter        1   8.9  61  1001.0  0.1
# ...               ...    ...  ..  ...     ...      ...   ...  ..     ...  ...
# 17914         Tourism  Woman  43  ...  Winter        1  17.2  57  1020.7  0.0
# 17308      Motorcycle  Woman  48  ...  Winter        1  12.8  74  1011.7  0.0
# 17378      Motorcycle    Man  27  ...  Winter        1  12.4  56  1001.0  0.3
# 17912         Bicycle    Man  48  ...  Winter        1  17.2  57  1020.7  0.0
# 17599         Tourism  Woman  51  ...  Winter        2  14.2  86  1024.3  0.0
#
#        RS24h  VVM10  Time_segment  Number of victims by time segment
# 0        1.5    1.9           0-6                                  2
# 2        1.5    1.9         12-18                                  5
# 7        1.5    1.9         18-23                                  7
# 10       1.5    1.9         18-23                                  7
# 6        1.5    1.9         12-18                                  5
# ...      ...    ...           ...                                ...
# 17914    8.7    1.9         18-23                                  5
# 17308    7.0    0.9          6-12                                  2
# 17378    7.4    2.6           0-6                                 10
# 17912    8.7    1.9         12-18                                 10
# 17599    7.2    1.1          6-12                                 11
#
# [14206 rows x 30 columns]

# %%
grouped_df = df.groupby(['Time_segment', 'Day']).size().reset_index(name='Accident_Count')
mean_accidents = grouped_df.groupby('Time_segment')['Accident_Count'].mean().reset_index(name='Mean_Accidents')

desired_order = ['6-12', '12-18', '18-23', '0-6']


plt.figure(figsize=(12, 6))
sns.barplot(x='Time_segment', y='Mean_Accidents', data=mean_accidents, order=desired_order)

# Configuración adicional
#plt.title('Media de Accidentes de Tráfico por Franja Horaria al Día')
plt.xlabel('Time segment')
plt.ylabel('Average traffic accidents per day')
plt.xticks(rotation=45, ha='right')

# Mostrar el gráfico
plt.show()

# %%
df['Exceeds_Threshold'] = df['Number of victims by time segment'] >= 4


df['Exceeds_Threshold'] = df['Exceeds_Threshold'].astype(bool)

# %%
df
# Out:
#            Case_number District_name  Week_day  Year  Month  Day_month  Time  \
# 0      2021S000001         Les Corts    Friday  2021      1          1     0
# 2      2021S000002          Eixample    Friday  2021      1          1    12
# 7      2021S000003       Sant Andreu    Friday  2021      1          1    18
# 10     2021S000004          Eixample    Friday  2021      1          1    20
# 6      2021S000005            Gràcia    Friday  2021      1          1    12
# ...                ...           ...       ...   ...    ...        ...   ...
# 17914  2022S008011        Nou Barris  Saturday  2022     12         31    18
# 17308  2022S008012            Gràcia   Tuesday  2022     12          6    10
# 17378  2022S008013          Eixample  Saturday  2022     12         10     1
# 17912  2023S000004            Gràcia  Saturday  2022     12         31    15
# 17599  2023S000550          Eixample    Monday  2022     12         19     8
#
#       Type_of_vehicle    Sex Age  ... Density    TM HRM      PM  PPT  RS24h  \
# 0          Motorcycle    Man  24  ...       1   8.9  61  1001.0  0.1    1.5
# 2             Tourism  Woman  49  ...       1   8.9  61  1001.0  0.1    1.5
# 7             Tourism  Woman  46  ...       1   8.9  61  1001.0  0.1    1.5
# 10            Tourism  Woman  58  ...       1   8.9  61  1001.0  0.1    1.5
# 6          Motorcycle    Man  27  ...       1   8.9  61  1001.0  0.1    1.5
# ...               ...    ...  ..  ...     ...   ...  ..     ...  ...    ...
# 17914         Tourism  Woman  43  ...       1  17.2  57  1020.7  0.0    8.7
# 17308      Motorcycle  Woman  48  ...       1  12.8  74  1011.7  0.0    7.0
# 17378      Motorcycle    Man  27  ...       1  12.4  56  1001.0  0.3    7.4
# 17912         Bicycle    Man  48  ...       1  17.2  57  1020.7  0.0    8.7
# 17599         Tourism  Woman  51  ...       2  14.2  86  1024.3  0.0    7.2
#
#        VVM10  Time_segment  Number of victims by time segment  \
# 0        1.9           0-6                                  2
# 2        1.9         12-18                                  5
# 7        1.9         18-23                                  7
# 10       1.9         18-23                                  7
# 6        1.9         12-18                                  5
# ...      ...           ...                                ...
# 17914    1.9         18-23                                  5
# 17308    0.9          6-12                                  2
# 17378    2.6           0-6                                 10
# 17912    1.9         12-18                                 10
# 17599    1.1          6-12                                 11
#
#        Exceeds_Threshold
# 0                  False
# 2                   True
# 7                   True
# 10                  True
# 6                   True
# ...                  ...
# 17914               True
# 17308              False
# 17378               True
# 17912               True
# 17599               True
#
# [14206 rows x 31 columns]
