# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
df1=pd.read_csv('TFG_OFICIAL.csv')

# %%
df1
# Out:
#            Case_number  District_code        District_name  Neighborhood_code  \
# 0      2021S000001                  4            Les Corts                 21
# 1      2021S000001                  4            Les Corts                 21
# 2      2021S000002                  2             Eixample                  8
# 3      2021S000002                  2             Eixample                  8
# 4      2021S000002                  2             Eixample                  8
# ...                ...            ...                  ...                ...
# 17914  2022S008011                  8           Nou Barris                 48
# 17915  2022S008007                  8           Nou Barris                 44
# 17916  2022S008007                  8           Nou Barris                 44
# 17917  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17918  2022S008009                  5  Sarrià-Sant Gervasi                 26
#
# ...

# %%
import datetime

def is_holiday(day, day_of_week):
    # Create a dictionary of holiday dates
    holidays = {
        '01/01/2021': 'New Year',
        '06/01/2021': 'Epiphany',
        '02/04/2021': 'Divendres Sant',
        '05/04/2021': 'Pascua',
        '01/05/2021': 'Mayo',
        '24/05/2021': 'Sant Joan1',
        '24/06/2021': 'Sant Joan',
        '11/09/2021': 'Asumpcio',
        '24/09/2021': 'Merce',
        '12/10/2021': 'Hispanidad',
        '01/11/2021': 'Tots sants',
        '06/12/2021': 'Constitucio',
        '08/12/2021': 'Constitucio2',
        '25/12/2021': 'St Esteve',
        '01/01/2022': 'New Year',
        '06/01/2022': 'Epiphany',
        '15/04/2022': 'Divendres Sant',
        '18/04/2022': 'Pascua',
        '06/06/2022': 'Pascua 2',
        '24/06/2022': 'Sant Joan',
        '15/08/2022': 'Asumpcio',
        '24/09/2022': 'Merce',
        '26/09/2022': 'Merce2',
        '12/10/2022': 'Hispanidad',
        '01/11/2022': 'Tots sants',
        '06/12/2022': 'Constitucio',
        '08/12/2022': 'Constitucio2',
        '26/12/2022': 'St Esteve',
    }
    # Check if the day is a holiday or weekend
    if day in holidays or day_of_week in ['Saturday', 'Sunday']:
        return 'Yes'
    else:
        return 'No'

# Assuming 'Dia' contains the date and 'Day' contains the day of the week
df1['Holiday'] = df1.apply(lambda row: is_holiday(row['Day'], row['Week_day']), axis=1)

# %%
import datetime

def is_holiday(day, day_of_week):
    # Create a dictionary of holiday dates
    holidays = {
        '05/04/2021': 'New Year',
        '24/05/2021': 'Epiphany',
        '12/10/2021': 'Divendres Sant',
        '01/11/2021': 'Pascua',
        '8/12/2021': 'Mayo',
        '18/04/2022': 'Sant Joan1',
        '06/06/2022': 'Sant Joan',
        '15/08/2022': 'Asumpcio',
        '01/11/2022': 'Merce',
        '06/12/2022': 'Hispanidad',
        '26/12/2022': 'Hispanidad'
      
    }
    # Check if the day is a holiday or weekend
    if day in holidays or day_of_week in ['Sunday']:
        return 'Yes'
    else:
        return 'No'

# Assuming 'Dia' contains the date and 'Day' contains the day of the week
df1['Weekend Return'] = df1.apply(lambda row: is_holiday(row['Day'], row['Week_day']), axis=1)

# %%
df1.rename(columns={'Weekend Exists': 'Weekend Exit'}, inplace=True)

# %%
df1['Number of accidents by time segment'] = df1.groupby(['Day', 'Time_segment'])['Case_number'].transform('nunique')

df1.drop_duplicates(subset='Case_number', keep='first', inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14207 entries, 0 to 17917
# Data columns (total 47 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Case_number                          14207 non-null  object
#  1   District_code                        14207 non-null  int64
#  2   District_name                        14207 non-null  object
#  3   Neighborhood_code                    14207 non-null  int64
#  4   Neighborhood_name                    14207 non-null  object
#  5   Street_code                          14207 non-null  int64
#  6   Street_name                          14207 non-null  object
#  7   Postal_number                        14207 non-null  object
#  8   Week_day                             14207 non-null  object
#  9   Year                                 14207 non-null  int64
#  10  Month                                14207 non-null  int64
# ...

# %%
df1 = df1.drop(columns=['Coordinate_UTM_X_ED50 '], axis=1)
df1 = df1.drop(columns=['Coordinate_UTM_Y_ED50'], axis=1)
df1.drop(['Longitude'], axis=1, inplace=True)
df1.drop(['Latitude'], axis=1, inplace=True)
df1.drop(['Pedestrian_displacement_motive'], axis=1, inplace=True)
df1.drop(['Month_name'], axis=1, inplace=True)
df1.drop(['Type_of_vehicle'], axis=1, inplace=True)
df1.drop(['Vacation_day'], axis=1, inplace=True)
df1.drop(['RS24h'], axis=1, inplace=True)

df1.drop(['PM'], axis=1, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14207 entries, 0 to 17917
# Data columns (total 37 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Case_number                          14207 non-null  object
#  1   District_code                        14207 non-null  int64
#  2   District_name                        14207 non-null  object
#  3   Neighborhood_code                    14207 non-null  int64
#  4   Neighborhood_name                    14207 non-null  object
#  5   Street_code                          14207 non-null  int64
#  6   Street_name                          14207 non-null  object
#  7   Postal_number                        14207 non-null  object
#  8   Week_day                             14207 non-null  object
#  9   Year                                 14207 non-null  int64
#  10  Month                                14207 non-null  int64
# ...

# %%
df1.drop(['District_code'], axis=1, inplace=True)
df1.drop(['Case_number'], axis=1, inplace=True)
df1.drop(['Neighborhood_code'], axis=1, inplace=True)
df1.drop(['Postal_number'], axis=1, inplace=True)
df1.drop(['Street_name'], axis=1, inplace=True)
df1.drop(['Street_code'], axis=1, inplace=True)
df1.drop(['Year'], axis=1, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14207 entries, 0 to 17917
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   District_name                        14207 non-null  object
#  1   Neighborhood_name                    14207 non-null  object
#  2   Week_day                             14207 non-null  object
#  3   Month                                14207 non-null  int64
#  4   Day_month                            14207 non-null  int64
#  5   Shift                                14207 non-null  object
#  6   Time                                 14207 non-null  int64
#  7   Pedestrian_cause                     14207 non-null  object
#  8   Sex                                  14207 non-null  object
#  9   Age                                  14207 non-null  object
#  10  Person_type                          14207 non-null  object
# ...

# %%
df1.drop(['Neighborhood_name'], axis=1, inplace=True)
df1.drop(['Day_month'], axis=1, inplace=True)
df1.drop(['Shift'], axis=1, inplace=True)
df1.drop(['Pedestrian_cause'], axis=1, inplace=True)
df1.drop(['Driver_displacement_motive'], axis=1, inplace=True)
df1.drop(['Street_name'], axis=1, inplace=True)
df1.drop(['Street_code'], axis=1, inplace=True)
df1.drop(['Year'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-931e5a1a4c15> in <module>
#       4 df1.drop(['Pedestrian_cause'], axis=1, inplace=True)
#       5 df1.drop(['Driver_displacement_motive'], axis=1, inplace=True)
# ----> 6 df1.drop(['Street_name'], axis=1, inplace=True)
#       7 df1.drop(['Street_code'], axis=1, inplace=True)
#       8 df1.drop(['Year'], axis=1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4899                 weight  1.0     0.8
#    4900         """
# -> 4901         return super().drop(
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14207 entries, 0 to 17917
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   District_name                        14207 non-null  object
#  1   Week_day                             14207 non-null  object
#  2   Month                                14207 non-null  int64
#  3   Time                                 14207 non-null  int64
#  4   Sex                                  14207 non-null  object
#  5   Age                                  14207 non-null  object
#  6   Person_type                          14207 non-null  object
#  7   Pedestrian_collision_place           14207 non-null  object
#  8   Injury_severity                      14207 non-null  object
#  9   Day                                  14207 non-null  object
#  10  Holiday                              14207 non-null  object
# ...

# %%
df1.drop(['Pedestrian_collision_place'], axis=1, inplace=True)
df1.drop(['Person_type'], axis=1, inplace=True)
df1.drop(['Number of victims'], axis=1, inplace=True)
df1.drop(['Slightly injured'], axis=1, inplace=True)
df1.drop(['Severely injured'], axis=1, inplace=True)

# %%
df1.drop(['Severely injured'], axis=1, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14207 entries, 0 to 17917
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   District_name                        14207 non-null  object
#  1   Week_day                             14207 non-null  object
#  2   Month                                14207 non-null  int64
#  3   Time                                 14207 non-null  int64
#  4   Sex                                  14207 non-null  object
#  5   Age                                  14207 non-null  object
#  6   Injury_severity                      14207 non-null  object
#  7   Day                                  14207 non-null  object
#  8   Holiday                              14207 non-null  object
#  9   Time_segment                         14207 non-null  object
#  10  Numero_expedient_count               14207 non-null  int64
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14207 entries, 0 to 17917
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   District_name                        14207 non-null  object
#  1   Week_day                             14207 non-null  object
#  2   Month                                14207 non-null  int64
#  3   Time                                 14207 non-null  int64
#  4   Sex                                  14207 non-null  object
#  5   Age                                  14207 non-null  object
#  6   Injury_severity                      14207 non-null  object
#  7   Day                                  14207 non-null  object
#  8   Holiday                              14207 non-null  object
#  9   Time_segment                         14207 non-null  object
#  10  Numero_expedient_count               14207 non-null  int64
# ...

# %%
df1.drop(['Numero_expedient_count'], axis=1, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14207 entries, 0 to 17917
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   District_name                        14207 non-null  object
#  1   Week_day                             14207 non-null  object
#  2   Month                                14207 non-null  int64
#  3   Time                                 14207 non-null  int64
#  4   Sex                                  14207 non-null  object
#  5   Age                                  14207 non-null  object
#  6   Injury_severity                      14207 non-null  object
#  7   Day                                  14207 non-null  object
#  8   Holiday                              14207 non-null  object
#  9   Time_segment                         14207 non-null  object
#  10  Weekend Exit                         14207 non-null  bool
# ...

# %%
df1.to_csv('tfg.csv', index=False)
