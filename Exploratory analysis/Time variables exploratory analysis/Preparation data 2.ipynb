# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
df=pd.read_csv('TFG.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14206 entries, 0 to 14205
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case_number             14206 non-null  object
#  1   District_name           14206 non-null  object
#  2   Week_day                14206 non-null  object
#  3   Year                    14206 non-null  int64
#  4   Month_name              14206 non-null  object
#  5   Day_month               14206 non-null  int64
#  6   Type_of_vehicle         14206 non-null  object
#  7   Sex                     14206 non-null  object
#  8   Age                     14206 non-null  object
#  9   Person_type             14206 non-null  object
#  10  Injury_severity         14206 non-null  int64
#  11  Day                     14206 non-null  object
#  12  Time_segment            14206 non-null  object
#  13  Vacation_day            14206 non-null  bool
#  14  Numero_expedient_count  14206 non-null  int64
#  15  Number of victims       14206 non-null  int64
#  16  Slightly injured        14206 non-null  int64
#  17  Severely injured        14206 non-null  int64
#  18  Weekend Exists          14206 non-null  bool
#  19  Season                  14206 non-null  object
#  20  Density                 14206 non-null  int64
#  21  TM                      14206 non-null  float64
#  22  HRM                     14206 non-null  int64
#  23  PM                      14206 non-null  float64
#  24  PPT                     14206 non-null  float64
#  25  RS24h                   14206 non-null  float64
#  26  VVM10                   14206 non-null  float64
#  27  Exceeds_Threshold       14206 non-null  bool
# dtypes: bool(3), float64(5), int64(9), object(11)
# memory usage: 2.8+ MB

# %%
import pandas as pd

# Suponiendo que tu DataFrame se llama 'df'
# Crear la columna 'Number of victims by time segment'
df['Number of victims by time segment'] = df.groupby(['Day', 'Time_segment'])['Numero_expedient_count'].transform('sum')

# Verificar los cambios
print(df[['Day', 'Time_segment', 'Numero_expedient_count', 'Number of victims by time segment']].head())
# Out:
#           Day Time_segment  Numero_expedient_count  \
# 0  01/01/2021      Leisure                       2
# 1  01/01/2021      Morning                       4
# 2  01/01/2021    Afternoon                       3
# 3  01/01/2021    Afternoon                       4
# 4  01/01/2021      Morning                       1
#
#    Number of victims by time segment
# 0                                  2
# 1                                  5
# 2                                  7
# 3                                  7
# 4                                  5

# %%
df['Day'], df['Time_segment'], df['Numero_expedient_count'], df['Number of victims by time segment']
# Out:
# (0        01/01/2021
#  1        01/01/2021
#  2        01/01/2021
#  3        01/01/2021
#  4        01/01/2021
#              ...
#  14201    31/12/2022
#  14202    06/12/2022
#  14203    10/12/2022
#  14204    31/12/2022
#  14205    19/12/2022
#  Name: Day, Length: 14206, dtype: object,
#  0               Leisure
#  1               Morning
#  2             Afternoon
#  3             Afternoon
#  4               Morning
#                ...
#  14201         Afternoon
#  14202           Morning
#  14203           Leisure
#  14204    Work Departure
#  14205     Work Entrance
#  Name: Time_segment, Length: 14206, dtype: object,
#  0        2
#  1        4
#  2        3
#  3        4
#  4        1
#          ..
#  14201    1
#  14202    1
#  14203    1
#  14204    1
#  14205    1
#  Name: Numero_expedient_count, Length: 14206, dtype: int64,
#  0        2
#  1        5
#  2        7
#  3        7
#  4        5
#          ..
#  14201    5
#  14202    2
#  14203    8
#  14204    4
#  14205    7
#  Name: Number of victims by time segment, Length: 14206, dtype: int64)

# %%
df
# Out:
#            Case_number District_name  Week_day  Year Month_name  Day_month  \
# 0      2021S000001         Les Corts    Friday  2021    January          1
# 1      2021S000002          Eixample    Friday  2021    January          1
# 2      2021S000003       Sant Andreu    Friday  2021    January          1
# 3      2021S000004          Eixample    Friday  2021    January          1
# 4      2021S000005            Gràcia    Friday  2021    January          1
# ...                ...           ...       ...   ...        ...        ...
# 14201  2022S008011        Nou Barris  Saturday  2022   December         31
# 14202  2022S008012            Gràcia   Tuesday  2022   December          6
# 14203  2022S008013          Eixample  Saturday  2022   December         10
# 14204  2023S000004            Gràcia  Saturday  2022   December         31
# 14205  2023S000550          Eixample    Monday  2022   December         19
#
#       Type_of_vehicle    Sex Age Person_type  ...  Season Density    TM  HRM  \
# 0          Motorcycle    Man  24      Driver  ...  Winter       1   8.9   61
# 1             Tourism  Woman  49   Passenger  ...  Winter       1   8.9   61
# 2             Tourism  Woman  46   Passenger  ...  Winter       1   8.9   61
# 3             Tourism  Woman  58   Passenger  ...  Winter       1   8.9   61
# 4          Motorcycle    Man  27      Driver  ...  Winter       1   8.9   61
# ...               ...    ...  ..         ...  ...     ...     ...   ...  ...
# 14201         Tourism  Woman  43   Passenger  ...  Winter       1  17.2   57
# 14202      Motorcycle  Woman  48      Driver  ...  Winter       1  12.8   74
# 14203      Motorcycle    Man  27      Driver  ...  Winter       1  12.4   56
# 14204         Bicycle    Man  48      Driver  ...  Winter       1  17.2   57
# 14205         Tourism  Woman  51  Pedestrian  ...  Winter       2  14.2   86
#
#            PM  PPT  RS24h  VVM10  Exceeds_Threshold  \
# 0      1001.0  0.1    1.5    1.9              False
# 1      1001.0  0.1    1.5    1.9              False
# 2      1001.0  0.1    1.5    1.9              False
# 3      1001.0  0.1    1.5    1.9              False
# 4      1001.0  0.1    1.5    1.9              False
# ...       ...  ...    ...    ...                ...
# 14201  1020.7  0.0    8.7    1.9              False
# 14202  1011.7  0.0    7.0    0.9              False
# 14203  1001.0  0.3    7.4    2.6              False
# 14204  1020.7  0.0    8.7    1.9              False
# 14205  1024.3  0.0    7.2    1.1              False
#
#       Number of victims by time segment
# 0                                     2
# 1                                     5
# 2                                     7
# 3                                     7
# 4                                     5
# ...                                 ...
# 14201                                 5
# 14202                                 2
# 14203                                 8
# 14204                                 4
# 14205                                 7
#
# [14206 rows x 29 columns]

# %%
df.drop('Exceeds_Threshold', axis=1, inplace=True)

# %%
df['Exceeds_Threshold'] = df['Number of victims by time segment'] >= 4


df['Exceeds_Threshold'] = df['Exceeds_Threshold'].astype(bool)

# %%
df
# Out:
#            Case_number District_name  Week_day  Year Month_name  Day_month  \
# 0      2021S000001         Les Corts    Friday  2021    January          1
# 1      2021S000002          Eixample    Friday  2021    January          1
# 2      2021S000003       Sant Andreu    Friday  2021    January          1
# 3      2021S000004          Eixample    Friday  2021    January          1
# 4      2021S000005            Gràcia    Friday  2021    January          1
# ...                ...           ...       ...   ...        ...        ...
# 14201  2022S008011        Nou Barris  Saturday  2022   December         31
# 14202  2022S008012            Gràcia   Tuesday  2022   December          6
# 14203  2022S008013          Eixample  Saturday  2022   December         10
# 14204  2023S000004            Gràcia  Saturday  2022   December         31
# 14205  2023S000550          Eixample    Monday  2022   December         19
#
#       Type_of_vehicle    Sex Age Person_type  ...  Season Density    TM  HRM  \
# 0          Motorcycle    Man  24      Driver  ...  Winter       1   8.9   61
# 1             Tourism  Woman  49   Passenger  ...  Winter       1   8.9   61
# 2             Tourism  Woman  46   Passenger  ...  Winter       1   8.9   61
# 3             Tourism  Woman  58   Passenger  ...  Winter       1   8.9   61
# 4          Motorcycle    Man  27      Driver  ...  Winter       1   8.9   61
# ...               ...    ...  ..         ...  ...     ...     ...   ...  ...
# 14201         Tourism  Woman  43   Passenger  ...  Winter       1  17.2   57
# 14202      Motorcycle  Woman  48      Driver  ...  Winter       1  12.8   74
# 14203      Motorcycle    Man  27      Driver  ...  Winter       1  12.4   56
# 14204         Bicycle    Man  48      Driver  ...  Winter       1  17.2   57
# 14205         Tourism  Woman  51  Pedestrian  ...  Winter       2  14.2   86
#
#            PM  PPT  RS24h  VVM10  Number of victims by time segment  \
# 0      1001.0  0.1    1.5    1.9                                  2
# 1      1001.0  0.1    1.5    1.9                                  5
# 2      1001.0  0.1    1.5    1.9                                  7
# 3      1001.0  0.1    1.5    1.9                                  7
# 4      1001.0  0.1    1.5    1.9                                  5
# ...       ...  ...    ...    ...                                ...
# 14201  1020.7  0.0    8.7    1.9                                  5
# 14202  1011.7  0.0    7.0    0.9                                  2
# 14203  1001.0  0.3    7.4    2.6                                  8
# 14204  1020.7  0.0    8.7    1.9                                  4
# 14205  1024.3  0.0    7.2    1.1                                  7
#
#       Exceeds_Threshold
# 0                 False
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# ...                 ...
# 14201              True
# 14202             False
# 14203              True
# 14204              True
# 14205              True
#
# [14206 rows x 29 columns]

# %%
df.to_csv('TFG_proba.csv',index=False)
