# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
df=pd.read_csv('Accidents21-22.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17919 entries, 0 to 17918
# Data columns (total 37 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Case_number                     17919 non-null  object
#  1   District_code                   17919 non-null  int64
#  2   District_name                   17919 non-null  object
#  3   Neighborhood_code               17919 non-null  int64
#  4   Neighborhood_name               17919 non-null  object
#  5   Street_code                     17919 non-null  int64
#  6   Street_name                     17919 non-null  object
#  7   Postal_number                   17919 non-null  object
#  8   Week_day                        17919 non-null  object
#  9   Year                            17919 non-null  int64
#  10  Month                           17919 non-null  int64
#  11  Month_name                      17919 non-null  object
# ...

# %%
df.rename(inplace=True, columns={'Nom_carrer': 'Street_name'})
df.rename(inplace=True, columns={'Num_postal': 'Postal_number'})
df.rename(inplace=True, columns={'Descripcio_dia_setmana': 'Week_day'})
df.rename(inplace=True, columns={'NK_ Any': 'Year'})
df.rename(inplace=True, columns={'Mes_ any': 'Month'})
df.rename(inplace=True, columns={'Nom_mes': 'Month_name'})
df.rename(inplace=True, columns={'Dia_mes': 'Day_month'})
df.rename(inplace=True, columns={'Descripcio_torn': 'Shift'})
df.rename(inplace=True, columns={'Hora_dia': 'Time'})
df.rename(inplace=True, columns={'Descripcio_causa_vianant': 'Pedestrian_cause'})
df.rename(inplace=True, columns={'Desc_Tipus_vehicle_implicat': 'Type_of_vehicle'})
df.rename(inplace=True, columns={'Descripcio_sexe': 'Sex'})
df.rename(inplace=True, columns={'Edat': 'Age'})
df.rename(inplace=True, columns={'Descripcio_tipus_persona': 'Person_type'})
df.rename(inplace=True, columns={'Descripcio_Lloc_atropellament_vianant': 'Pedestrian_collision_place'})
df.rename(inplace=True, columns={'Descripcio_Motiu_desplaçament_vianant': 'Pedestrian_displacement_motive'})
df.rename(inplace=True, columns={'Descripcio_Motiu_desplaçament_conductor': 'Driver_displacement_motive'})
df.rename(inplace=True, columns={'Descripcio_victimitzacio': 'Injury_severity'})
df.rename(inplace=True, columns={'Coordenada_UTM_X_ED50': 'Coordinate_UTM_X_ED50 '})
df.rename(inplace=True, columns={'Coordenada_UTM_Y_ED50': 'Coordinate_UTM_Y_ED50'})
df.rename(inplace=True, columns={'Longitud': 'Longitude'})
df.rename(inplace=True, columns={'Latitud': 'Latitude'})
df.rename(inplace=True, columns={'Dia': 'Day'})
df.rename(inplace=True, columns={'Franja_horaria': 'Time_segment'})
df.rename(inplace=True, columns={'Dies_Festa': 'Vacation_day'})
df.rename(inplace=True, columns={'Ponts': 'Long_weekend'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17919 entries, 0 to 17918
# Data columns (total 37 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Case_number                     17919 non-null  object
#  1   District_code                   17919 non-null  int64
#  2   District_name                   17919 non-null  object
#  3   Neighborhood_code               17919 non-null  int64
#  4   Neighborhood_name               17919 non-null  object
#  5   Street_code                     17919 non-null  int64
#  6   Street_name                     17919 non-null  object
#  7   Postal_number                   17919 non-null  object
#  8   Week_day                        17919 non-null  object
#  9   Year                            17919 non-null  int64
#  10  Month                           17919 non-null  int64
#  11  Month_name                      17919 non-null  object
# ...

# %%
df['Long_weekend'].value_counts()
# Out:
# Nothing         17471
# Sortida Pont      448
# Name: Long_weekend, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17919 entries, 0 to 17918
# Data columns (total 37 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Case_number                     17919 non-null  object
#  1   District_code                   17919 non-null  int64
#  2   District_name                   17919 non-null  object
#  3   Neighborhood_code               17919 non-null  int64
#  4   Neighborhood_name               17919 non-null  object
#  5   Street_code                     17919 non-null  int64
#  6   Street_name                     17919 non-null  object
#  7   Postal_number                   17919 non-null  object
#  8   Week_day                        17919 non-null  object
#  9   Year                            17919 non-null  int64
#  10  Month                           17919 non-null  int64
#  11  Month_name                      17919 non-null  object
# ...

# %%
df['Case_number'].describe()
# Out:
# count               17919
# unique              14207
# top       2021S003925
# freq                   12
# Name: Case_number, dtype: object

# %%
sns.factorplot(x='District_name', data=df, kind='count', palette='Set1',order=df['District_name'].value_counts().index)
plt.title('District_name')
plt.xlabel('District_name', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
df['District_name'].value_counts()
# Out:
# Eixample               5081
# Sant Martí             2290
# Sants-Montjuïc         1931
# Sarrià-Sant Gervasi    1893
# Horta-Guinardó         1368
# Les Corts              1232
# Sant Andreu            1209
# Nou Barris             1001
# Ciutat Vella            951
# Gràcia                  841
# Desconegut              122
# Name: District_name, dtype: int64

# %%
def remove_duplicates(df):
    df = df.drop_duplicates(subset=['Case_number'])
    return df

# %%
df
# Out:
#            Case_number  District_code        District_name  Neighborhood_code  \
# 0      2021S000004                  2             Eixample                  5
# 1      2021S000004                  2             Eixample                  5
# 2      2021S000004                  2             Eixample                  5
# 3      2021S000004                  2             Eixample                  5
# 4      2021S000002                  2             Eixample                  8
# ...                ...            ...                  ...                ...
# 17914  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17915  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17916  2022S008010                  5  Sarrià-Sant Gervasi                 26
# 17917  2022S008011                  8           Nou Barris                 48
# 17918  2023S000004                  6               Gràcia                 28
#
# ...

# %%
df_drop=df

# %%
df_drop
# Out:
#            Case_number  District_code        District_name  Neighborhood_code  \
# 0      2021S000004                  2             Eixample                  5
# 1      2021S000004                  2             Eixample                  5
# 2      2021S000004                  2             Eixample                  5
# 3      2021S000004                  2             Eixample                  5
# 4      2021S000002                  2             Eixample                  8
# ...                ...            ...                  ...                ...
# 17914  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17915  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17916  2022S008010                  5  Sarrià-Sant Gervasi                 26
# 17917  2022S008011                  8           Nou Barris                 48
# 17918  2023S000004                  6               Gràcia                 28
#
# ...

# %%
df_drop.to_csv('tot_sense_repetits.csv', index=False)

# %%
df.to_csv('Accidents21-22.csv',index=False)

# %%
df_drop
# Out:
#            Case_number  District_code        District_name  Neighborhood_code  \
# 0      2021S000004                  2             Eixample                  5
# 1      2021S000004                  2             Eixample                  5
# 2      2021S000004                  2             Eixample                  5
# 3      2021S000004                  2             Eixample                  5
# 4      2021S000002                  2             Eixample                  8
# ...                ...            ...                  ...                ...
# 17914  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17915  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17916  2022S008010                  5  Sarrià-Sant Gervasi                 26
# 17917  2022S008011                  8           Nou Barris                 48
# 17918  2023S000004                  6               Gràcia                 28
#
# ...

# %%
 df_drop= remove_duplicates(df_drop)

# %%
remove_duplicates(df_drop)
# Out:
#            Case_number  District_code        District_name  Neighborhood_code  \
# 0      2021S000004                  2             Eixample                  5
# 4      2021S000002                  2             Eixample                  8
# 8      2021S000001                  4            Les Corts                 21
# 10     2021S000005                  6               Gràcia                 32
# 11     2021S000003                  9          Sant Andreu                 57
# ...                ...            ...                  ...                ...
# 17912  2022S008007                  8           Nou Barris                 44
# 17914  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17916  2022S008010                  5  Sarrià-Sant Gervasi                 26
# 17917  2022S008011                  8           Nou Barris                 48
# 17918  2023S000004                  6               Gràcia                 28
#
# ...

# %%
df
# Out:
#            Case_number  District_code        District_name  Neighborhood_code  \
# 0      2021S000004                  2             Eixample                  5
# 1      2021S000004                  2             Eixample                  5
# 2      2021S000004                  2             Eixample                  5
# 3      2021S000004                  2             Eixample                  5
# 4      2021S000002                  2             Eixample                  8
# ...                ...            ...                  ...                ...
# 17914  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17915  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17916  2022S008010                  5  Sarrià-Sant Gervasi                 26
# 17917  2022S008011                  8           Nou Barris                 48
# 17918  2023S000004                  6               Gràcia                 28
#
# ...

# %%
sns.factorplot(x='District_name', data=df_drop, kind='count', palette='Set1',order=df['District_name'].value_counts().index)
plt.title('District_name')
plt.xlabel('District_name', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
df_drop
# Out:
#            Case_number  District_code        District_name  Neighborhood_code  \
# 0      2021S000004                  2             Eixample                  5
# 4      2021S000002                  2             Eixample                  8
# 8      2021S000001                  4            Les Corts                 21
# 10     2021S000005                  6               Gràcia                 32
# 11     2021S000003                  9          Sant Andreu                 57
# ...                ...            ...                  ...                ...
# 17912  2022S008007                  8           Nou Barris                 44
# 17914  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17916  2022S008010                  5  Sarrià-Sant Gervasi                 26
# 17917  2022S008011                  8           Nou Barris                 48
# 17918  2023S000004                  6               Gràcia                 28
#
# ...

# %%
df_drop['District_name'].value_counts()
# Out:
# Eixample               4105
# Sant Martí             1790
# Sants-Montjuïc         1505
# Sarrià-Sant Gervasi    1503
# Horta-Guinardó         1059
# Sant Andreu             962
# Les Corts               961
# Nou Barris              772
# Ciutat Vella            757
# Gràcia                  699
# Desconegut               94
# Name: District_name, dtype: int64

# %%
df['District_name'].value_counts()
# Out:
# Eixample               5081
# Sant Martí             2290
# Sants-Montjuïc         1931
# Sarrià-Sant Gervasi    1893
# Horta-Guinardó         1368
# Les Corts              1232
# Sant Andreu            1209
# Nou Barris             1001
# Ciutat Vella            951
# Gràcia                  841
# Desconegut              122
# Name: District_name, dtype: int64

# %%
df['Injury_severity'].value_counts()
# Out:
# Hospitalized         12046
# Slight Assistance     4367
# Slight                1127
# Severe                 343
# Dead                    35
# Natural Death            1
# Name: Injury_severity, dtype: int64

# %%
acc=pd.read_csv('2021_2022_motius - 2021_accidents_causes_gu_bcn_.csv')

# %%
acc.info(9)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15642 entries, 0 to 15641
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Numero_expedient          15642 non-null  object
#  1   Descripcio_causa_mediata  15642 non-null  object
# dtypes: object(2)
# memory usage: 244.5+ KB

# %%
acc['Descripcio_causa_mediata'].value_counts()
# Out:
# No hi ha causa mediata             14462
# Alcoholèmia                          875
# Calçada en mal estat                 119
# Excés de velocitat o inadequada       81
# Objectes o animals a la calçada       42
# Drogues o medicaments                 30
# Estat de la senyalització             16
# Factors meteorològics                 16
# Descripcio_causa_mediata               1
# Name: Descripcio_causa_mediata, dtype: int64

# %%
values=acc['Descripcio_causa_mediata'].value_counts()

# Create a circular graph with the given values
#plt.pie(values, autopct='%1.1f%%')
plt.pie(values, autopct='%1.1f%%', startangle=45)
plt.legend(acc['Descripcio_causa_mediata'], loc='best')
# Show the graph
plt.show()

# %%
values=acc['Descripcio_causa_mediata'].value_counts()

# Get the top 3 most repeated values
top3_values = values.index.values[:3]

# Create a circular graph with the given values
plt.pie(values.loc[top3_values], autopct='%1.1f%%', startangle=45)

# Change the legend format
plt.legend(top3_values, loc='best', title='Causas de Mediación')

# Show the graph
plt.show()

# %%
values=acc['Descripcio_causa_mediata'].value_counts()

# Get the top 3 most repeated values
top3_values = values.index.values[1:]
valors=values.index.values[1:4]

# Create a circular graph with the given values
plt.pie(values.loc[top3_values], autopct='%1.1f%%', startangle=45)

# Change the legend format
plt.legend(valors, loc='best', title='Causas de Mediación')

# Show the graph
plt.show()

# %%
df_drop['Time_segment'].value_counts()
# Out:
# Work Departure    4110
# Morning           3268
# Afternoon         3265
# Work Entrance     2144
# Leisure           1101
# Matinada           319
# Name: Time_segment, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17919 entries, 0 to 17918
# Data columns (total 37 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Case_number                     17919 non-null  object
#  1   District_code                   17919 non-null  int64
#  2   District_name                   17919 non-null  object
#  3   Neighborhood_code               17919 non-null  int64
#  4   Neighborhood_name               17919 non-null  object
#  5   Street_code                     17919 non-null  int64
#  6   Street_name                     17919 non-null  object
#  7   Postal_number                   17919 non-null  object
#  8   Week_day                        17919 non-null  object
#  9   Year                            17919 non-null  int64
#  10  Month                           17919 non-null  int64
#  11  Month_name                      17919 non-null  object
# ...

# %%
values = df_drop['Time_segment'].value_counts()
valors = values.index.values
plt.pie(values, autopct='%1.1f%%', startangle=45)
plt.legend(valors, loc='best', title='Time segment')
plt.show()

# %%
df['Time_segment'].value_counts()
# Out:
# Work Departure    5165
# Afternoon         4200
# Morning           4094
# Work Entrance     2570
# Leisure           1435
# Matinada           455
# Name: Time_segment, dtype: int64

# %%
df['Injury_severity'].value_counts(normalize=True)
# Out:
# Hospitalized         0.672247
# Slight Assistance    0.243708
# Slight               0.062894
# Severe               0.019142
# Dead                 0.001953
# Natural Death        0.000056
# Name: Injury_severity, dtype: float64

# %%
df_drop['District_name'].value_counts(normalize=True)
# Out:
# Eixample               0.288942
# Sant Martí             0.125994
# Sants-Montjuïc         0.105934
# Sarrià-Sant Gervasi    0.105793
# Horta-Guinardó         0.074541
# Sant Andreu            0.067713
# Les Corts              0.067643
# Nou Barris             0.054339
# Ciutat Vella           0.053284
# Gràcia                 0.049201
# Desconegut             0.006616
# Name: District_name, dtype: float64

# %%
df['Time_segment'].value_counts()
# Out:
# Work Departure    5165
# Afternoon         4200
# Morning           4094
# Work Entrance     2570
# Leisure           1435
# Matinada           455
# Name: Time_segment, dtype: int64

# %%
sns.displot(df_drop, x="Time_segment", hue="Sex" , multiple="dodge")
plt.xlabel('Injury_severity', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Afternoon'),
#   Text(1, 0, 'Morning'),
#   Text(2, 0, 'Leisure'),
#   Text(3, 0, 'Work Departure'),
#   Text(4, 0, 'Work Entrance'),
#   Text(5, 0, 'Matinada')])

# %%
import pandas as pd

accidents = df_drop.groupby('Injury_severity', as_index=False).agg({'Time_segment': 'count'}).rename(columns={'Time_segment': 'Times'})
print(accidents)
# Out:
#      Injury_severity  Times
# 0               Dead     30
# 1       Hospitalized   9890
# 2      Natural Death      1
# 3             Severe    283
# 4             Slight    710
# 5  Slight Assistance   3293

# %%
pd.crosstab(index=df_drop['Time_segment'],
            columns=df_drop['Injury_severity'], margins=True)
# Out:
# Injury_severity  Dead  Hospitalized  Natural Death  Severe  Slight  \
# Time_segment
# Afternoon           5          2373              0      69     118
# Leisure             4           731              0      46      63
# Matinada            4           212              0      17      19
# Morning             6          2163              1      49     170
# Work Departure      7          3011              0      70     209
# Work Entrance       4          1400              0      32     131
# All                30          9890              1     283     710
#
# Injury_severity  Slight Assistance    All
# Time_segment
# Afternoon                      700   3265
# Leisure                        257   1101
# Matinada                        67    319
# Morning                        879   3268
# Work Departure                 813   4110
# Work Entrance                  577   2144
# All                           3293  14207

# %%
pd.crosstab(index=df_drop['Time_segment'],
            columns=df_drop['Injury_severity'], margins=True).apply(lambda r: r/len(df_drop) *100, axis=1)
# Out:
# Injury_severity      Dead  Hospitalized  Natural Death    Severe    Slight  \
# Time_segment
# Afternoon        0.035194     16.703034       0.000000  0.485676  0.830576
# Leisure          0.028155      5.145351       0.000000  0.323784  0.443443
# Matinada         0.028155      1.492222       0.000000  0.119659  0.133737
# Morning          0.042233     15.224889       0.007039  0.344900  1.196593
# Work Departure   0.049271     21.193778       0.000000  0.492715  1.471106
# Work Entrance    0.028155      9.854297       0.000000  0.225241  0.922081
# All              0.211164     69.613571       0.007039  1.991976  4.997536
#
# Injury_severity  Slight Assistance         All
# Time_segment
# Afternoon                 4.927149   22.981629
# Leisure                   1.808967    7.749701
# Matinada                  0.471599    2.245372
# Morning                   6.187091   23.002745
# Work Departure            5.722531   28.929401
# Work Entrance             4.061378   15.091152
# ...

# %%
plot = pd.crosstab(index=df_drop['Injury_severity'],
            columns=df_drop['Time_segment']).apply(lambda r: r/r.sum() *100,
                                              axis=1).plot(kind='bar')

# %%
pd.crosstab(index=df_drop['Time_segment'],
            columns=df_drop['Sex'], margins=True).apply(lambda r: r/len(df_drop) *100, axis=1)
# Out:
# Sex                   Man   Unknown      Woman         All
# Time_segment
# Afternoon       12.789470  0.000000  10.192159   22.981629
# Leisure          5.032730  0.007039   2.709932    7.749701
# Matinada         1.555571  0.007039   0.682762    2.245372
# Morning         13.331456  0.007039   9.664250   23.002745
# Work Departure  16.280707  0.014078  12.634617   28.929401
# Work Entrance    8.157950  0.000000   6.933202   15.091152
# All             57.147885  0.035194  42.816921  100.000000

# %%
 df_drop['Time_segment']
# Out:
# 0             Afternoon
# 4               Morning
# 8               Leisure
# 10              Morning
# 11            Afternoon
#               ...
# 17912         Afternoon
# 17914         Afternoon
# 17916    Work Departure
# 17917         Afternoon
# 17918    Work Departure
# Name: Time_segment, Length: 14207, dtype: object

# %%
df['Time_segment'] = df['Time_segment'].replace(['Tarda', 'Matí', 'Oci', 'Sortida Feina', 'Entrada Feina'], ['Afternoon', 'Morning', 'Leisure', 'Work Departure', 'Work Entrance'])
df_drop['Time_segment'] = df_drop['Time_segment'].replace(['Tarda', 'Matí', 'Oci', 'Sortida Feina', 'Entrada Feina'], ['Afternoon', 'Morning', 'Leisure', 'Work Departure', 'Work Entrance'])
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df['Time_segment'].value_counts()
# Out:
# Work Departure    5165
# Afternoon         4200
# Morning           4094
# Work Entrance     2570
# Leisure           1435
# Matinada           455
# Name: Time_segment, dtype: int64

# %%
df['Injury_severity'].value_counts()
# Out:
# Hospitalized         12046
# Slight Assistance     4367
# Slight                1127
# Severe                 343
# Dead                    35
# Natural Death            1
# Name: Injury_severity, dtype: int64

# %%
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
df['Injury_severity'] = df['Injury_severity'].replace(['Ferit lleu: Hospitalització fins a 24h', "Ferit lleu: Amb assistència sanitària en lloc d'accident", 'Ferit lleu: Rebutja assistència sanitària', 'Ferit greu: hospitalització superior a 24h', 'Mort (dins 24h posteriors accident)', 'Mort natural'], ['Hospitalized', 'Slight Assistance', 'Slight', 'Severe', 'Dead', 'Natural Death'])
df_drop['Injury_severity'] = df_drop['Injury_severity'].replace(['Ferit lleu: Hospitalització fins a 24h', "Ferit lleu: Amb assistència sanitària en lloc d'accident", 'Ferit lleu: Rebutja assistència sanitària', 'Ferit greu: hospitalització superior a 24h', 'Mort (dins 24h posteriors accident)', 'Mort natural'], ['Hospitalized', 'Slight Assistance', 'Slight', 'Severe', 'Dead', 'Natural Death'])

# %%
df['Injury_severity'].value_counts()
# Out:
# Hospitalized         12046
# Slight Assistance     4367
# Slight                1127
# Severe                 343
# Dead                    35
# Natural Death            1
# Name: Injury_severity, dtype: int64

# %%
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
df
# Out:
#            Case_number  District_code        District_name  Neighborhood_code  \
# 0      2021S000004                  2             Eixample                  5
# 1      2021S000004                  2             Eixample                  5
# 2      2021S000004                  2             Eixample                  5
# 3      2021S000004                  2             Eixample                  5
# 4      2021S000002                  2             Eixample                  8
# ...                ...            ...                  ...                ...
# 17914  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17915  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17916  2022S008010                  5  Sarrià-Sant Gervasi                 26
# 17917  2022S008011                  8           Nou Barris                 48
# 17918  2023S000004                  6               Gràcia                 28
#
# ...

# %%
df['Long_weekend'] = df['Long_weekend'].replace(['Res', 'Pont'], ['Nothing', 'Lond weekend'])
df_drop['Long_weekend'] = df_drop['Long_weekend'].replace(['Res', 'Pont'], ['Nothing', 'Lond weekend'])
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df
# Out:
#            Case_number  District_code        District_name  Neighborhood_code  \
# 0      2021S000004                  2             Eixample                  5
# 1      2021S000004                  2             Eixample                  5
# 2      2021S000004                  2             Eixample                  5
# 3      2021S000004                  2             Eixample                  5
# 4      2021S000002                  2             Eixample                  8
# ...                ...            ...                  ...                ...
# 17914  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17915  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17916  2022S008010                  5  Sarrià-Sant Gervasi                 26
# 17917  2022S008011                  8           Nou Barris                 48
# 17918  2023S000004                  6               Gràcia                 28
#
# ...

# %%
df['Long_weekend'].value_counts()
# Out:
# Nothing         17471
# Sortida Pont      448
# Name: Long_weekend, dtype: int64

# %%
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
df['Week_day'] = df['Week_day'].replace(['Dilluns', 'Dimarts', 'Dimecres', 'Dijous', 'Divendres', 'Dissabte', 'Diumenge'], ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
df_drop['Week_day'] = df_drop['Week_day'].replace(['Dilluns', 'Dimarts', 'Dimecres', 'Dijous', 'Divendres', 'Dissabte', 'Diumenge'], ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17919 entries, 0 to 17918
# Data columns (total 37 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Case_number                     17919 non-null  object
#  1   District_code                   17919 non-null  int64
#  2   District_name                   17919 non-null  object
#  3   Neighborhood_code               17919 non-null  int64
#  4   Neighborhood_name               17919 non-null  object
#  5   Street_code                     17919 non-null  int64
#  6   Street_name                     17919 non-null  object
#  7   Postal_number                   17919 non-null  object
#  8   Week_day                        17919 non-null  object
#  9   Year                            17919 non-null  int64
#  10  Month                           17919 non-null  int64
#  11  Month_name                      17919 non-null  object
# ...

# %%
df['Month_name'].value_counts()
# Out:
# May          1681
# November     1674
# October      1652
# June         1614
# July         1601
# December     1587
# September    1489
# March        1477
# April        1411
# February     1352
# January      1257
# August       1124
# Name: Month_name, dtype: int64

# %%
df['Month_name'] = df['Month_name'].replace(['Gener', 'Febrer', 'Març', 'Abril', 'Maig', 'Juny', 'Juliol', 'Agost', 'Setembre', 'Octubre', 'Novembre', 'Desembre'], ['January', 'February', 'March', 'April', 'May', 'June', 'July','August', 'September', 'October', 'November', 'December'])
df_drop['Month_name'] = df_drop['Month_name'].replace(['Gener', 'Febrer', 'Març', 'Abril', 'Maig', 'Juny', 'Juliol', 'Agost', 'Setembre', 'Octubre', 'Novembre', 'Desembre'], ['January', 'February', 'March', 'April', 'May', 'June', 'July','August', 'September', 'October', 'November', 'December'])

# %%
df['Month_name']
# Out:
# 0         January
# 1         January
# 2         January
# 3         January
# 4         January
#            ...
# 17914    December
# 17915    December
# 17916    December
# 17917    December
# 17918    December
# Name: Month_name, Length: 17919, dtype: object

# %%
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
df['Shift'].value_counts()
# Out:
# Afternoon    9365
# Morning      6664
# Night        1890
# Name: Shift, dtype: int64

# %%
df['Shift'] = df['Shift'].replace(['Tarda', 'Matí', 'Nit'], ['Afternoon', 'Morning', 'Night'])
df_drop['Shift'] = df_drop['Shift'].replace(['Tarda', 'Matí', 'Nit'], ['Afternoon', 'Morning', 'Night'])
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14207 entries, 0 to 17918
# Data columns (total 37 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Case_number                     14207 non-null  object
#  1   District_code                   14207 non-null  int64
#  2   District_name                   14207 non-null  object
#  3   Neighborhood_code               14207 non-null  int64
#  4   Neighborhood_name               14207 non-null  object
#  5   Street_code                     14207 non-null  int64
#  6   Street_name                     14207 non-null  object
#  7   Postal_number                   14207 non-null  object
#  8   Week_day                        14207 non-null  object
#  9   Year                            14207 non-null  int64
#  10  Month                           14207 non-null  int64
#  11  Month_name                      14207 non-null  object
# ...

# %%
df['Pedestrian_cause'].value_counts()
# Out:
# Not pedestrian´s fault                16677
# Disobey light traffic signal            482
# Cross over the pedestrian crossing      418
# Other                                   238
# Walk along the road                     101
# Disobey other signals                     3
# Name: Pedestrian_cause, dtype: int64

# %%
#Type of vehicle, Pedestrian_displacement_motive, Driver_displacement_motive

# %%
 df['Sex'] = df['Sex'].replace(['Home', 'Dona', 'Desconegut'], ['Man', 'Woman', 'Unknown'])
df_drop['Sex'] = df_drop['Sex'].replace(['Home', 'Dona', 'Desconegut'], ['Man', 'Woman', 'Unknown'])
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
df['Person_type'] = df['Person_type'].replace(['Conductor', 'Passatger', 'Vianant'], ['Driver', 'Passenger', 'Pedestrian'])
df_drop['Person_type'] = df_drop['Person_type'].replace(['Conductor', 'Passatger', 'Vianant'], ['Driver', 'Passenger', 'Pedestrian'])
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
df['Pedestrian_cause'] = df['Pedestrian_cause'].replace(['No és causa del  vianant', 'Desobeir el senyal del semàfor', 'Creuar per fora pas de vianants', 'Altres', 'Transitar a peu per la calçada', 'Desobeir altres senyals'], ['Not pedestrian´s fault', 'Disobey light traffic signal', 'Cross over the pedestrian crossing', 'Other', 'Walk along the road', 'Disobey other signals'])
df_drop['Pedestrian_cause'] = df_drop['Pedestrian_cause'].replace(['No és causa del  vianant', 'Desobeir el senyal del semàfor', 'Creuar per fora pas de vianants', 'Altres', 'Transitar a peu per la calçada', 'Desobeir altres senyals'], ['Not pedestrian´s fault', 'Disobey light traffic signal', 'Cross over the pedestrian crossing', 'Other', 'Walk along the road', 'Disobey other signals'])
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
df['Driver_displacement_motive'].value_counts()
# Out:
# Desconegut                                     5242
# Es desconeix                                   4985
# Oci i entreteniment                            2976
# In itínere                                     2516
# En missió                                       992
# Altres activitats                               809
# Taxi                                            169
# Bombers, policia, ambulància                     85
# Transport professional de mercaderies            54
# Estudiant cap a centre d'estudis                 28
# Bus urbà                                         24
# Activitat esportiva particular                   13
# Bus de línia regular                              7
# En pràctiques d'autoescola                        6
# Servei de neteja o recollida d'escombraries       4
# Servei d'auxili en carretera                      3
# Transport de menors a l'escola                    2
# Servei de manteniment viari                       2
# ...

# %%
df['Pedestrian_collision_place']= df['Pedestrian_collision_place'].replace(['Desconegut', 'En pas regulat per semàfor', 'Fora del pas', 'A la vorera / Andana', 'En pas sense regular', 'Altres', 'En zona peatonal', 'En pas sense senyalitzar'], ['Unknown', 'Crossing regulated by traffic lights', 'Over the crossing path', 'Sidewalk', 'Crossing not regulated', 'Other' , 'Pedestrian area', 'Unmarked passage'])
df_drop['Pedestrian_collision_place'] = df_drop['Pedestrian_collision_place'].replace(['Desconegut', 'En pas regulat per semàfor', 'Fora del pas', 'A la vorera / Andana', 'En pas sense regular', 'Altres', 'En zona peatonal', 'En pas sense senyalitzar'], ['Unknown', 'Crossing regulated by traffic lights', 'Over the crossing path', 'Sidewalk', 'Crossing not regulated', 'Other' , 'Pedestrian area', 'Unmarked passage'])
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
acc
# Out:
#       Numero_expedient Descripcio_causa_mediata
# 0      2021S000001       No hi ha causa mediata
# 1      2021S000005       No hi ha causa mediata
# 2      2021S000002                  Alcoholèmia
# 3      2021S000004       No hi ha causa mediata
# 4      2021S000003                  Alcoholèmia
# ...                ...                      ...
# 15637  2022S003404       No hi ha causa mediata
# 15638  2022S003378       No hi ha causa mediata
# 15639  2022S003389       No hi ha causa mediata
# 15640  2022S003396       No hi ha causa mediata
# 15641  2022S003393       No hi ha causa mediata
#
# [15642 rows x 2 columns]

# %%
df['Numero_expedient_count'] = df['Case_number'].apply(lambda x: df[df['Case_number'] == x].shape[0])

# Create a new column in the second dataframe and fill it with the corresponding count
df_drop['Number of vehicles involved'] = df_drop['Case_number'].apply(lambda x: df[df['Case_number'] == x].shape[0])
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df_drop
# Out:
#            Case_number  District_code        District_name  Neighborhood_code  \
# 0      2021S000004                  2             Eixample                  5
# 4      2021S000002                  2             Eixample                  8
# 8      2021S000001                  4            Les Corts                 21
# 10     2021S000005                  6               Gràcia                 32
# 11     2021S000003                  9          Sant Andreu                 57
# ...                ...            ...                  ...                ...
# 17912  2022S008007                  8           Nou Barris                 44
# 17914  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17916  2022S008010                  5  Sarrià-Sant Gervasi                 26
# 17917  2022S008011                  8           Nou Barris                 48
# 17918  2023S000004                  6               Gràcia                 28
#
# ...

# %%
df.head(20)
# Out:
#         Case_number  District_code District_name  Neighborhood_code  \
# 0   2021S000004                  2      Eixample                  5
# 1   2021S000004                  2      Eixample                  5
# 2   2021S000004                  2      Eixample                  5
# 3   2021S000004                  2      Eixample                  5
# 4   2021S000002                  2      Eixample                  8
# 5   2021S000002                  2      Eixample                  8
# 6   2021S000002                  2      Eixample                  8
# 7   2021S000002                  2      Eixample                  8
# 8   2021S000001                  4     Les Corts                 21
# 9   2021S000001                  4     Les Corts                 21
# 10  2021S000005                  6        Gràcia                 32
# 11  2021S000003                  9   Sant Andreu                 57
# 12  2021S000003                  9   Sant Andreu                 57
# ...

# %%
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
df['Number of victims'] = df['Injury_severity'].apply(lambda x: int(x == 'Dead') if x else int(0))

# %%
df.head(50)
# Out:
#         Case_number  District_code        District_name  Neighborhood_code  \
# 0   2021S000004                  2             Eixample                  5
# 1   2021S000004                  2             Eixample                  5
# 2   2021S000004                  2             Eixample                  5
# 3   2021S000004                  2             Eixample                  5
# 4   2021S000002                  2             Eixample                  8
# 5   2021S000002                  2             Eixample                  8
# 6   2021S000002                  2             Eixample                  8
# 7   2021S000002                  2             Eixample                  8
# 8   2021S000001                  4            Les Corts                 21
# 9   2021S000001                  4            Les Corts                 21
# 10  2021S000005                  6               Gràcia                 32
# ...

# %%
df['Number of victims'].value_counts()
# Out:
# 0    17884
# 1       35
# Name: Number of victims, dtype: int64

# %%
df['Injury_severity'].value_counts()
# Out:
# Hospitalized         12046
# Slight Assistance     4367
# Slight                1127
# Severe                 343
# Dead                    35
# Natural Death            1
# Name: Injury_severity, dtype: int64

# %%
expedient_dict = df['Case_number'].value_counts().index

# Iterate through the unique strings and count the number of 1s in the 'Number of victims' column
for expedient in expedient_dict:
    count = df[df['Case_number'] == expedient]['Number of victims'].sum()

    # Add the count to the second DataFrame in the 'Number of victims' column
    df_drop.loc[df_drop['Case_number'] == expedient, 'Number of victims'] = count
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.head(1232)
# Out:
#           Case_number  District_code        District_name  Neighborhood_code  \
# 0     2021S000004                  2             Eixample                  5
# 1     2021S000004                  2             Eixample                  5
# 2     2021S000004                  2             Eixample                  5
# 3     2021S000004                  2             Eixample                  5
# 4     2021S000002                  2             Eixample                  8
# ...               ...            ...                  ...                ...
# 1227  2021S001050                 10           Sant Martí                 66
# 1228  2021S001047                 10           Sant Martí                 71
# 1229  2021S001056                  7       Horta-Guinardó                 43
# 1230  2021S001054                  5  Sarrià-Sant Gervasi                 25
# 1231  2021S001068                  2             Eixample                  6
#
# ...

# %%
df_drop.head(987)
# Out:
#           Case_number  District_code        District_name  Neighborhood_code  \
# 0     2021S000004                  2             Eixample                  5
# 4     2021S000002                  2             Eixample                  8
# 8     2021S000001                  4            Les Corts                 21
# 10    2021S000005                  6               Gràcia                 32
# 11    2021S000003                  9          Sant Andreu                 57
# ...               ...            ...                  ...                ...
# 1230  2021S001054                  5  Sarrià-Sant Gervasi                 25
# 1231  2021S001068                  2             Eixample                  6
# 1232  2021S001070                  2             Eixample                  8
# 1233  2021S001067                  3       Sants-Montjuïc                 13
# 1234  2021S001064                  4            Les Corts                 19
#
# ...

# %%
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14207 entries, 0 to 17918
# Data columns (total 38 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Case_number                     14207 non-null  object
#  1   District_code                   14207 non-null  int64
#  2   District_name                   14207 non-null  object
#  3   Neighborhood_code               14207 non-null  int64
#  4   Neighborhood_name               14207 non-null  object
#  5   Street_code                     14207 non-null  int64
#  6   Street_name                     14207 non-null  object
#  7   Postal_number                   14207 non-null  object
#  8   Week_day                        14207 non-null  object
#  9   Year                            14207 non-null  int64
#  10  Month                           14207 non-null  int64
#  11  Month_name                      14207 non-null  object
# ...

# %%
df_drop['Number of victims'] = df_drop['Number of victims'].astype(int)
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df_drop.head(987)
# Out:
#           Case_number  District_code        District_name  Neighborhood_code  \
# 0     2021S000004                  2             Eixample                  5
# 4     2021S000002                  2             Eixample                  8
# 8     2021S000001                  4            Les Corts                 21
# 10    2021S000005                  6               Gràcia                 32
# 11    2021S000003                  9          Sant Andreu                 57
# ...               ...            ...                  ...                ...
# 1230  2021S001054                  5  Sarrià-Sant Gervasi                 25
# 1231  2021S001068                  2             Eixample                  6
# 1232  2021S001070                  2             Eixample                  8
# 1233  2021S001067                  3       Sants-Montjuïc                 13
# 1234  2021S001064                  4            Les Corts                 19
#
# ...

# %%
df['Slightly injured'] = df['Injury_severity'].apply(lambda x: 1 if x in ['Slight', 'Slight Assistance'] else 0)

# %%
df['Injury_severity'][3]
# Out:
# 'Hospitalized'

# %%
df.head(50)
# Out:
#         Case_number  District_code        District_name  Neighborhood_code  \
# 0   2021S000004                  2             Eixample                  5
# 1   2021S000004                  2             Eixample                  5
# 2   2021S000004                  2             Eixample                  5
# 3   2021S000004                  2             Eixample                  5
# 4   2021S000002                  2             Eixample                  8
# 5   2021S000002                  2             Eixample                  8
# 6   2021S000002                  2             Eixample                  8
# 7   2021S000002                  2             Eixample                  8
# 8   2021S000001                  4            Les Corts                 21
# 9   2021S000001                  4            Les Corts                 21
# 10  2021S000005                  6               Gràcia                 32
# ...

# %%
expedient_dict = df['Case_number'].value_counts().index

# Iterate through the unique strings and count the number of 1s in the 'Number of victims' column
for expedient in expedient_dict:
    count = df[df['Case_number'] == expedient]['Slightly injured'].sum()
    df_drop.loc[df_drop['Case_number'] == expedient, 'Slightly injured'] = count
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_drop
# Out:
#            Case_number  District_code        District_name  Neighborhood_code  \
# 0      2021S000004                  2             Eixample                  5
# 4      2021S000002                  2             Eixample                  8
# 8      2021S000001                  4            Les Corts                 21
# 10     2021S000005                  6               Gràcia                 32
# 11     2021S000003                  9          Sant Andreu                 57
# ...                ...            ...                  ...                ...
# 17912  2022S008007                  8           Nou Barris                 44
# 17914  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17916  2022S008010                  5  Sarrià-Sant Gervasi                 26
# 17917  2022S008011                  8           Nou Barris                 48
# 17918  2023S000004                  6               Gràcia                 28
#
# ...

# %%
df_drop['Slightly injured']
# Out:
# 0        0
# 4        4
# 8        0
# 10       0
# 11       1
#         ..
# 17912    0
# 17914    1
# 17916    1
# 17917    1
# 17918    1
# Name: Slightly injured, Length: 14207, dtype: int64

# %%
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
df_drop['Slightly injured'] = df_drop['Slightly injured'].astype(int)
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df_drop
# Out:
#            Case_number  District_code        District_name  Neighborhood_code  \
# 0      2021S000004                  2             Eixample                  5
# 4      2021S000002                  2             Eixample                  8
# 8      2021S000001                  4            Les Corts                 21
# 10     2021S000005                  6               Gràcia                 32
# 11     2021S000003                  9          Sant Andreu                 57
# ...                ...            ...                  ...                ...
# 17912  2022S008007                  8           Nou Barris                 44
# 17914  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17916  2022S008010                  5  Sarrià-Sant Gervasi                 26
# 17917  2022S008011                  8           Nou Barris                 48
# 17918  2023S000004                  6               Gràcia                 28
#
# ...

# %%
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
df['Severely injured'] = df['Injury_severity'].apply(lambda x: 1 if x in ['Severe', 'Hospitalized'] else 0)
expedient_dict = df['Case_number'].value_counts().index

# Iterate through the unique strings and count the number of 1s in the 'Number of victims' column
for expedient in expedient_dict:
    count = df[df['Case_number'] == expedient]['Severely injured'].sum()
    df_drop.loc[df_drop['Case_number'] == expedient, 'Severely injured'] = count

# %%
df_drop['Severely injured'] = df_drop['Severely injured'].astype(int)
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df[6:20]
# Out:
#         Case_number  District_code District_name  Neighborhood_code  \
# 6   2021S000002                  2      Eixample                  8
# 7   2021S000002                  2      Eixample                  8
# 8   2021S000001                  4     Les Corts                 21
# 9   2021S000001                  4     Les Corts                 21
# 10  2021S000005                  6        Gràcia                 32
# 11  2021S000003                  9   Sant Andreu                 57
# 12  2021S000003                  9   Sant Andreu                 57
# 13  2021S000003                  9   Sant Andreu                 57
# 14  2021S000014                  2      Eixample                  8
# 15  2021S000020                  8    Nou Barris                 48
# 16  2021S000017                  1  Ciutat Vella                  2
# 17  2021S000017                  1  Ciutat Vella                  2
# 18  2021S000021                  1  Ciutat Vella                  4
# ...

# %%
df_drop
# Out:
#            Case_number  District_code        District_name  Neighborhood_code  \
# 0      2021S000004                  2             Eixample                  5
# 4      2021S000002                  2             Eixample                  8
# 8      2021S000001                  4            Les Corts                 21
# 10     2021S000005                  6               Gràcia                 32
# 11     2021S000003                  9          Sant Andreu                 57
# ...                ...            ...                  ...                ...
# 17912  2022S008007                  8           Nou Barris                 44
# 17914  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17916  2022S008010                  5  Sarrià-Sant Gervasi                 26
# 17917  2022S008011                  8           Nou Barris                 48
# 17918  2023S000004                  6               Gràcia                 28
#
# ...

# %%
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
acc['Descripcio_causa_mediata'].value_counts()
# Out:
# No hi ha causa mediata             14462
# Alcoholèmia                          875
# Calçada en mal estat                 119
# Excés de velocitat o inadequada       81
# Objectes o animals a la calçada       42
# Drogues o medicaments                 30
# Estat de la senyalització             16
# Factors meteorològics                 16
# Descripcio_causa_mediata               1
# Name: Descripcio_causa_mediata, dtype: int64

# %%
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14207 entries, 0 to 17918
# Data columns (total 38 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Case_number                     14207 non-null  object
#  1   District_code                   14207 non-null  int64
#  2   District_name                   14207 non-null  object
#  3   Neighborhood_code               14207 non-null  int64
#  4   Neighborhood_name               14207 non-null  object
#  5   Street_code                     14207 non-null  int64
#  6   Street_name                     14207 non-null  object
#  7   Postal_number                   14207 non-null  object
#  8   Week_day                        14207 non-null  object
#  9   Year                            14207 non-null  int64
#  10  Month                           14207 non-null  int64
#  11  Month_name                      14207 non-null  object
# ...

# %%
acc.rename(inplace=True, columns={'Numero_expedient': 'Case_number'})

# %%
acc= remove_duplicates(acc)

# %%
acc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12242 entries, 0 to 12241
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Case_number               12242 non-null  object
#  1   Descripcio_causa_mediata  12242 non-null  object
# dtypes: object(2)
# memory usage: 286.9+ KB

# %%
df['Type_of_vehicle'].value_counts()
#df['Pedestrian_collision_place']= df['Pedestrian_collision_place'].replace(['Desconegut', 'En pas regulat per semàfor', 'Fora del pas', 'A la vorera / Andana', 'En pas sense regular', 'Altres', 'En zona peatonal', 'En pas sense senyalitzar'], ['Unknown', 'Crossing regulated by traffic lights', 'Over the crossing path', 'Sidewalk', 'Crossing not regulated', 'Other' , 'Pedestrian area', 'Unmarked passage'])
#df_drop['Pedestrian_collision_place'] = df_drop['Pedestrian_collision_place'].replace(['Desconegut', 'En pas regulat per semàfor', 'Fora del pas', 'A la vorera / Andana', 'En pas sense regular', 'Altres', 'En zona peatonal', 'En pas sense senyalitzar'], ['Unknown', 'Crossing regulated by traffic lights', 'Over the crossing path', 'Sidewalk', 'Crossing not regulated', 'Other' , 'Pedestrian area', 'Unmarked passage'])
# Out:
# Motorcycle                              8410
# Tourism                                 3416
# Veh. motor personal mobility            1514
# Bicycle                                 1401
# Ciclomotor                              1031
# Bus                                      716
# Van                                      405
# Articulated bus                          392
# Taxi                                     339
# Other                                     62
# Rigid truck <= 3.5 tonnes                 49
# SUV                                       47
# Rigid truck > 3.5 tonnes                  44
# Ambulance                                 21
# Train or tram                             13
# Tractor truck                             13
# Quadricycle < 75 cc                       11
# Veh. personal mobility without motor       9
# Unknown                                    8
# Construction and service machinery         4
# Quadricycle > 75 cc                        3
# ...

# %%
df['Type_of_vehicle']= df['Type_of_vehicle'].replace(['Motocicleta', 'Turisme', 'Veh. mobilitat personal amb motor', 'Bicicleta', 'Ciclomotor', 'Autobús', 'Furgoneta', 'Autobús articulat', 'Taxi', 'Altres vehicles amb motor', 'Camió rígid <= 3,5 tones', 'Tot terreny', 'Camió rígid > 3,5 tones', 'Ambulància', 'Tren o tramvia', 'Tractor camió', 'Quadricicle < 75 cc','Veh. mobilitat personal sense motor', 'Desconegut', "Maquinària d'obres i serveis", 'Quadricicle > 75 cc', 'Autocar', 'Tricicle', 'Altres vehicles sense motor', 'Autocaravana', 'Pick-up'], ['Motorcycle', 'Tourism', 'Veh. motor personal mobility', 'Bicycle', 'Ciclomotor', 'Bus', 'Van', 'Articulated bus', 'Taxi', 'Other', 'Rigid truck <= 3.5 tonnes', 'SUV', 'Rigid truck > 3.5 tonnes', 'Ambulance', 'Train or tram', 'Tractor truck', 'Quadricycle < 75 cc', 'Veh. personal mobility without motor', 'Unknown', 'Construction and service machinery','Quadricycle > 75 cc', 'Coach', 'Tricycle', 'Other vehicles without engine', 'Motorhome', 'Pick up'])
df_drop['Type_of_vehicle']= df_drop['Type_of_vehicle'].replace(['Motocicleta', 'Turisme', 'Veh. mobilitat personal amb motor', 'Bicicleta', 'Ciclomotor', 'Autobús', 'Furgoneta', 'Autobús articulat', 'Taxi', 'Altres vehicles amb motor', 'Camió rígid <= 3,5 tones', 'Tot terreny', 'Camió rígid > 3,5 tones', 'Ambulància', 'Tren o tramvia', 'Tractor camió', 'Quadricicle < 75 cc','Veh. mobilitat personal sense motor', 'Desconegut', "Maquinària d'obres i serveis", 'Quadricicle > 75 cc', 'Autocar', 'Tricicle', 'Altres vehicles sense motor', 'Autocaravana', 'Pick-up'], ['Motorcycle', 'Tourism', 'Veh. motor personal mobility', 'Bicycle', 'Ciclomotor', 'Bus', 'Van', 'Articulated bus', 'Taxi', 'Other, ', 'Rigid truck <= 3.5 tonnes', 'SUV', 'Rigid truck > 3.5 tonnes', 'Ambulance', 'Train or tram', 'Tractor truck', 'Quadricycle < 75 cc', 'Veh. personal mobility without motor', 'Unknown', 'Construction and service machinery','Quadricycle > 75 cc', 'Coach', 'Tricycle', 'Other vehicles without engine', 'Motorhome', 'Pick up'])
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df['Type_of_vehicle'].value_counts()
# Out:
# Motorcycle                              8410
# Tourism                                 3416
# Veh. motor personal mobility            1514
# Bicycle                                 1401
# Ciclomotor                              1031
# Bus                                      716
# Van                                      405
# Articulated bus                          392
# Taxi                                     339
# Other                                     62
# Rigid truck <= 3.5 tonnes                 49
# SUV                                       47
# Rigid truck > 3.5 tonnes                  44
# Ambulance                                 21
# Train or tram                             13
# Tractor truck                             13
# Quadricycle < 75 cc                       11
# Veh. personal mobility without motor       9
# Unknown                                    8
# Construction and service machinery         4
# Quadricycle > 75 cc                        3
# ...

# %%
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)

# %%
df_drop
# Out:
#            Case_number  District_code        District_name  Neighborhood_code  \
# 0      2021S000004                  2             Eixample                  5
# 4      2021S000002                  2             Eixample                  8
# 8      2021S000001                  4            Les Corts                 21
# 10     2021S000005                  6               Gràcia                 32
# 11     2021S000003                  9          Sant Andreu                 57
# ...                ...            ...                  ...                ...
# 17912  2022S008007                  8           Nou Barris                 44
# 17914  2022S008009                  5  Sarrià-Sant Gervasi                 26
# 17916  2022S008010                  5  Sarrià-Sant Gervasi                 26
# 17917  2022S008011                  8           Nou Barris                 48
# 17918  2023S000004                  6               Gràcia                 28
#
# ...

# %%
# Replace the values in the 'Time_segment' column
df['Time_segment'] = df['Time_segment'].replace(['Matinada'], ['Early Morning'])
df_drop['Time_segment'] = df_drop['Time_segment'].replace(['Matinada'], ['Early Morning'])
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df_drop.to_csv('tot_sense_repetits.csv', index=False)
df.to_csv('Accidents21-22.csv',index=False)
