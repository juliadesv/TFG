# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn import tree
import pandas as pd
from sklearn import tree
from sklearn.model_selection import train_test_split
import numpy as np
from matplotlib import pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import itertools
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

def encoder(df, columns):
    mapeo = {'Yes': 1, 'No': 0}
    df['Holiday'] = df['Holiday'].map(mapeo)
    df['Weekend Return'] = df['Weekend Return'].map(mapeo)
    df = pd.get_dummies(df[columns], columns=columns)
    df = df.astype(float)
    return df



# Leer el dataset
df = pd.read_csv('dataset.csv')

# Definir todas las variables excepto la variable objetivo
variables = ['Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'PPT', 'TM', 'Week_day', 'Vacation_week']

# Generar todas las combinaciones posibles de 5 variables
combinations = list(itertools.combinations(variables, 5))

# Inicializar una lista para almacenar los resultados
results = []

# Iterar sobre cada combinación
# Iterar sobre cada combinación
for combo in combinations:
    # Hacer una copia del DataFrame original para cada combinación
    df_copy = df.copy()
    # Codificar solo las variables presentes en la combinación
    df_encoded = encoder(df_copy, list(combo))
    # Dividir el conjunto de datos en características (X) y objetivo (y)
    X = df_encoded
    y = df['Exceeds Threshold']
    split_index = int(len(df) * 0.85)
    X_train, X_test = X[:split_index], X[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    
    # Inicializar y entrenar el modelo XGBoost
    model = RandomForestClassifier(max_depth= 3, min_samples_split=5, n_estimators= 100, min_samples_leaf= 2)
    model.fit(X_train, y_train)
              
    # Realizar predicciones
    y_pred = model.predict(X_test)
    # Calcular la precisión
    accuracy = accuracy_score(y_test, y_pred)
    # Agregar los resultados a la lista
    results.append((combo, accuracy))


# Imprimir los resultados
for combo, accuracy in results:
    print("Variables:", combo)
    print("Accuracy:", accuracy)
# Out:
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'Season')
# Accuracy: 0.806697108066971
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'PPT')
# Accuracy: 0.8112633181126332
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'TM')
# Accuracy: 0.8082191780821918
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'Week_day')
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'Vacation_week')
# Accuracy: 0.8082191780821918
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'Season', 'PPT')
# Accuracy: 0.806697108066971
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'Season', 'TM')
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'Season', 'Week_day')
# Accuracy: 0.7732115677321156
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'Season', 'Vacation_week')
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'PPT', 'TM')
# Accuracy: 0.802130898021309
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'PPT', 'Week_day')
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'PPT', 'Vacation_week')
# Accuracy: 0.8006088280060882
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'TM', 'Week_day')
# Accuracy: 0.8112633181126332
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'TM', 'Vacation_week')
# Accuracy: 0.8036529680365296
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'Week_day', 'Vacation_week')
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'Season', 'PPT')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'Season', 'TM')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'Season', 'Week_day')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'Season', 'Vacation_week')
# Accuracy: 0.5981735159817352
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'PPT', 'TM')
# Accuracy: 0.5829528158295282
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'PPT', 'Week_day')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'PPT', 'Vacation_week')
# Accuracy: 0.5829528158295282
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'TM', 'Week_day')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'TM', 'Vacation_week')
# Accuracy: 0.5768645357686454
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'Week_day', 'Vacation_week')
# Accuracy: 0.5768645357686454
# Variables: ('Holiday', 'Weekend Return', 'Season', 'PPT', 'TM')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'Weekend Return', 'Season', 'PPT', 'Week_day')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'Weekend Return', 'Season', 'PPT', 'Vacation_week')
# Accuracy: 0.5981735159817352
# Variables: ('Holiday', 'Weekend Return', 'Season', 'TM', 'Week_day')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'Weekend Return', 'Season', 'TM', 'Vacation_week')
# Accuracy: 0.5981735159817352
# Variables: ('Holiday', 'Weekend Return', 'Season', 'Week_day', 'Vacation_week')
# Accuracy: 0.5920852359208524
# Variables: ('Holiday', 'Weekend Return', 'PPT', 'TM', 'Week_day')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'Weekend Return', 'PPT', 'TM', 'Vacation_week')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'Weekend Return', 'PPT', 'Week_day', 'Vacation_week')
# Accuracy: 0.5768645357686454
# Variables: ('Holiday', 'Weekend Return', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'Season', 'PPT')
# Accuracy: 0.8036529680365296
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'Season', 'TM')
# Accuracy: 0.8006088280060882
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'Season', 'Week_day')
# Accuracy: 0.806697108066971
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'Season', 'Vacation_week')
# Accuracy: 0.8036529680365296
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'PPT', 'TM')
# Accuracy: 0.791476407914764
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'PPT', 'Week_day')
# Accuracy: 0.776255707762557
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'PPT', 'Vacation_week')
# Accuracy: 0.8036529680365296
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'TM', 'Week_day')
# Accuracy: 0.8051750380517504
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'TM', 'Vacation_week')
# Accuracy: 0.7990867579908676
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'Week_day', 'Vacation_week')
# Accuracy: 0.7990867579908676
# Variables: ('Holiday', 'Time_Segment', 'Season', 'PPT', 'TM')
# Accuracy: 0.802130898021309
# Variables: ('Holiday', 'Time_Segment', 'Season', 'PPT', 'Week_day')
# Accuracy: 0.8082191780821918
# Variables: ('Holiday', 'Time_Segment', 'Season', 'PPT', 'Vacation_week')
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Time_Segment', 'Season', 'TM', 'Week_day')
# Accuracy: 0.8082191780821918
# Variables: ('Holiday', 'Time_Segment', 'Season', 'TM', 'Vacation_week')
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Time_Segment', 'Season', 'Week_day', 'Vacation_week')
# Accuracy: 0.802130898021309
# Variables: ('Holiday', 'Time_Segment', 'PPT', 'TM', 'Week_day')
# Accuracy: 0.806697108066971
# Variables: ('Holiday', 'Time_Segment', 'PPT', 'TM', 'Vacation_week')
# Accuracy: 0.8082191780821918
# Variables: ('Holiday', 'Time_Segment', 'PPT', 'Week_day', 'Vacation_week')
# Accuracy: 0.7975646879756468
# Variables: ('Holiday', 'Time_Segment', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.8006088280060882
# Variables: ('Holiday', 'VVM10', 'Season', 'PPT', 'TM')
# Accuracy: 0.5829528158295282
# Variables: ('Holiday', 'VVM10', 'Season', 'PPT', 'Week_day')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'VVM10', 'Season', 'PPT', 'Vacation_week')
# Accuracy: 0.5829528158295282
# Variables: ('Holiday', 'VVM10', 'Season', 'TM', 'Week_day')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'VVM10', 'Season', 'TM', 'Vacation_week')
# Accuracy: 0.5981735159817352
# Variables: ('Holiday', 'VVM10', 'Season', 'Week_day', 'Vacation_week')
# Accuracy: 0.5920852359208524
# Variables: ('Holiday', 'VVM10', 'PPT', 'TM', 'Week_day')
# Accuracy: 0.5829528158295282
# Variables: ('Holiday', 'VVM10', 'PPT', 'TM', 'Vacation_week')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'VVM10', 'PPT', 'Week_day', 'Vacation_week')
# Accuracy: 0.573820395738204
# Variables: ('Holiday', 'VVM10', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.573820395738204
# Variables: ('Holiday', 'Season', 'PPT', 'TM', 'Week_day')
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'Season', 'PPT', 'TM', 'Vacation_week')
# Accuracy: 0.5981735159817352
# Variables: ('Holiday', 'Season', 'PPT', 'Week_day', 'Vacation_week')
# Accuracy: 0.5951293759512938
# Variables: ('Holiday', 'Season', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.5981735159817352
# Variables: ('Holiday', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.5829528158295282
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'PPT')
# Accuracy: 0.7853881278538812
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'TM')
# Accuracy: 0.7838660578386606
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'Week_day')
# Accuracy: 0.8097412480974124
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'Vacation_week')
# Accuracy: 0.771689497716895
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'PPT', 'TM')
# Accuracy: 0.7838660578386606
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'PPT', 'Week_day')
# Accuracy: 0.8112633181126332
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'PPT', 'Vacation_week')
# Accuracy: 0.771689497716895
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'TM', 'Week_day')
# Accuracy: 0.8036529680365296
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'TM', 'Vacation_week')
# Accuracy: 0.7884322678843226
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'Week_day', 'Vacation_week')
# Accuracy: 0.8112633181126332
# Variables: ('Weekend Return', 'Time_Segment', 'Season', 'PPT', 'TM')
# Accuracy: 0.7701674277016742
# Variables: ('Weekend Return', 'Time_Segment', 'Season', 'PPT', 'Week_day')
# Accuracy: 0.7808219178082192
# Variables: ('Weekend Return', 'Time_Segment', 'Season', 'PPT', 'Vacation_week')
# Accuracy: 0.7701674277016742
# Variables: ('Weekend Return', 'Time_Segment', 'Season', 'TM', 'Week_day')
# Accuracy: 0.7792998477929984
# Variables: ('Weekend Return', 'Time_Segment', 'Season', 'TM', 'Vacation_week')
# Accuracy: 0.791476407914764
# Variables: ('Weekend Return', 'Time_Segment', 'Season', 'Week_day', 'Vacation_week')
# Accuracy: 0.7686453576864536
# Variables: ('Weekend Return', 'Time_Segment', 'PPT', 'TM', 'Week_day')
# Accuracy: 0.7732115677321156
# Variables: ('Weekend Return', 'Time_Segment', 'PPT', 'TM', 'Vacation_week')
# Accuracy: 0.7945205479452054
# Variables: ('Weekend Return', 'Time_Segment', 'PPT', 'Week_day', 'Vacation_week')
# Accuracy: 0.7853881278538812
# Variables: ('Weekend Return', 'Time_Segment', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.7686453576864536
# Variables: ('Weekend Return', 'VVM10', 'Season', 'PPT', 'TM')
# Accuracy: 0.5677321156773212
# Variables: ('Weekend Return', 'VVM10', 'Season', 'PPT', 'Week_day')
# Accuracy: 0.5829528158295282
# Variables: ('Weekend Return', 'VVM10', 'Season', 'PPT', 'Vacation_week')
# Accuracy: 0.5829528158295282
# Variables: ('Weekend Return', 'VVM10', 'Season', 'TM', 'Week_day')
# Accuracy: 0.5799086757990868
# Variables: ('Weekend Return', 'VVM10', 'Season', 'TM', 'Vacation_week')
# Accuracy: 0.589041095890411
# Variables: ('Weekend Return', 'VVM10', 'Season', 'Week_day', 'Vacation_week')
# Accuracy: 0.5768645357686454
# Variables: ('Weekend Return', 'VVM10', 'PPT', 'TM', 'Week_day')
# Accuracy: 0.5799086757990868
# Variables: ('Weekend Return', 'VVM10', 'PPT', 'TM', 'Vacation_week')
# Accuracy: 0.5799086757990868
# Variables: ('Weekend Return', 'VVM10', 'PPT', 'Week_day', 'Vacation_week')
# Accuracy: 0.5829528158295282
# Variables: ('Weekend Return', 'VVM10', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.5799086757990868
# Variables: ('Weekend Return', 'Season', 'PPT', 'TM', 'Week_day')
# Accuracy: 0.5859969558599696
# Variables: ('Weekend Return', 'Season', 'PPT', 'TM', 'Vacation_week')
# Accuracy: 0.5829528158295282
# Variables: ('Weekend Return', 'Season', 'PPT', 'Week_day', 'Vacation_week')
# Accuracy: 0.5951293759512938
# Variables: ('Weekend Return', 'Season', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.589041095890411
# Variables: ('Weekend Return', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.5829528158295282
# Variables: ('Time_Segment', 'VVM10', 'Season', 'PPT', 'TM')
# Accuracy: 0.7732115677321156
# Variables: ('Time_Segment', 'VVM10', 'Season', 'PPT', 'Week_day')
# Accuracy: 0.802130898021309
# Variables: ('Time_Segment', 'VVM10', 'Season', 'PPT', 'Vacation_week')
# Accuracy: 0.7701674277016742
# Variables: ('Time_Segment', 'VVM10', 'Season', 'TM', 'Week_day')
# Accuracy: 0.7656012176560122
# Variables: ('Time_Segment', 'VVM10', 'Season', 'TM', 'Vacation_week')
# Accuracy: 0.7792998477929984
# Variables: ('Time_Segment', 'VVM10', 'Season', 'Week_day', 'Vacation_week')
# Accuracy: 0.802130898021309
# Variables: ('Time_Segment', 'VVM10', 'PPT', 'TM', 'Week_day')
# Accuracy: 0.771689497716895
# Variables: ('Time_Segment', 'VVM10', 'PPT', 'TM', 'Vacation_week')
# Accuracy: 0.7656012176560122
# Variables: ('Time_Segment', 'VVM10', 'PPT', 'Week_day', 'Vacation_week')
# Accuracy: 0.771689497716895
# Variables: ('Time_Segment', 'VVM10', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.791476407914764
# Variables: ('Time_Segment', 'Season', 'PPT', 'TM', 'Week_day')
# Accuracy: 0.7960426179604262
# Variables: ('Time_Segment', 'Season', 'PPT', 'TM', 'Vacation_week')
# Accuracy: 0.7792998477929984
# Variables: ('Time_Segment', 'Season', 'PPT', 'Week_day', 'Vacation_week')
# Accuracy: 0.7899543378995434
# Variables: ('Time_Segment', 'Season', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.7732115677321156
# Variables: ('Time_Segment', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.8097412480974124
# Variables: ('VVM10', 'Season', 'PPT', 'TM', 'Week_day')
# Accuracy: 0.5799086757990868
# Variables: ('VVM10', 'Season', 'PPT', 'TM', 'Vacation_week')
# Accuracy: 0.528158295281583
# Variables: ('VVM10', 'Season', 'PPT', 'Week_day', 'Vacation_week')
# Accuracy: 0.5799086757990868
# Variables: ('VVM10', 'Season', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.5799086757990868
# Variables: ('VVM10', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.573820395738204
# Variables: ('Season', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Accuracy: 0.5981735159817352

# %%
# Filtrar combinaciones que superen el 81.25% de precisión
high_accuracy_combinations = [(combo, accuracy) for combo, accuracy in results if accuracy >  0.81]

# Imprimir las combinaciones que superen el 81.25% de precisión
for combo, accuracy in high_accuracy_combinations:
    print("Variables:", combo)
    print("Accuracy:", accuracy)
# Out:
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'PPT')
# Accuracy: 0.8112633181126332
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'TM', 'Week_day')
# Accuracy: 0.8112633181126332
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'PPT', 'Week_day')
# Accuracy: 0.8112633181126332
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'Week_day', 'Vacation_week')
# Accuracy: 0.8112633181126332
