# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn import tree
import pandas as pd
from sklearn import tree
from sklearn.model_selection import train_test_split
import numpy as np
from matplotlib import pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import itertools
from sklearn.preprocessing import LabelEncoder

def encoder(df, columns):
    mapeo = {'Yes': 1, 'No': 0}
    df['Holiday'] = df['Holiday'].map(mapeo)
    df['Weekend Return'] = df['Weekend Return'].map(mapeo)
    df = pd.get_dummies(df[columns], columns=columns)
    df = df.astype(float)
    return df

# Leer el dataset
df = pd.read_csv('dataset.csv')

# Definir todas las variables excepto la variable objetivo
variables = ['Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'PPT', 'TM', 'Week_day', 'Vacation_week']

# Generar todas las combinaciones posibles de 6 variables
combinations = list(itertools.combinations(variables, 4))

# Inicializar una lista para almacenar los resultados
results = []

# Iterar sobre cada combinación
for combo in combinations:
    # Hacer una copia del DataFrame original para cada combinación
    df_copy = df.copy()
    # Codificar solo las variables presentes en la combinación
    df_encoded = encoder(df_copy, list(combo))
    # Dividir el conjunto de datos en características (X) y objetivo (y)
    X = df_encoded
    y = df['Exceeds Threshold']
    split_index = int(len(df) * 0.85)
    X_train, X_test = X[:split_index], X[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    
    # Definir los hiperparámetros que deseas optimizar
    param_grid = {
        'max_depth': [5, 10, 15],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    }
    
    # Inicializar el modelo DecisionTreeClassifier
    model = DecisionTreeClassifier()
    
    # Inicializar GridSearchCV
    grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy')
    
    # Entrenar el modelo con Grid Search
    grid_search.fit(X_train, y_train)
    
    # Obtener la mejor combinación de hiperparámetros
    best_params = grid_search.best_params_
    
    # Crear el modelo con la mejor combinación de hiperparámetros
    best_model = DecisionTreeClassifier(**best_params)
    
    # Entrenar el mejor modelo
    best_model.fit(X_train, y_train)
    
    # Realizar predicciones
    y_pred = best_model.predict(X_test)
    
    # Calcular la precisión
    accuracy = accuracy_score(y_test, y_pred)
    
    # Agregar los resultados a la lista
    results.append((combo, best_params, accuracy))


# Imprimir los resultados
for combo, best_params, accuracy in results:
    print("Variables:", combo)
    print("Best Parameters:", best_params)
    print("Accuracy:", accuracy)
# Out:
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8006088280060882
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'Season')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8051750380517504
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'PPT')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.806697108066971
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'Season')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5981735159817352
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'PPT')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5646879756468798
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5753424657534246
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5920852359208524
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.589041095890411
# Variables: ('Holiday', 'Weekend Return', 'Season', 'PPT')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5799086757990868
# Variables: ('Holiday', 'Weekend Return', 'Season', 'TM')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.5920852359208524
# Variables: ('Holiday', 'Weekend Return', 'Season', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5829528158295282
# Variables: ('Holiday', 'Weekend Return', 'Season', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5981735159817352
# Variables: ('Holiday', 'Weekend Return', 'PPT', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5768645357686454
# Variables: ('Holiday', 'Weekend Return', 'PPT', 'Week_day')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5662100456621004
# Variables: ('Holiday', 'Weekend Return', 'PPT', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5799086757990868
# Variables: ('Holiday', 'Weekend Return', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.573820395738204
# Variables: ('Holiday', 'Weekend Return', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.589041095890411
# Variables: ('Holiday', 'Weekend Return', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5799086757990868
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'Season')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.7990867579908676
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'PPT')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8006088280060882
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8036529680365296
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'Week_day')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8006088280060882
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8036529680365296
# Variables: ('Holiday', 'Time_Segment', 'Season', 'PPT')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.7990867579908676
# Variables: ('Holiday', 'Time_Segment', 'Season', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.7960426179604262
# Variables: ('Holiday', 'Time_Segment', 'Season', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8051750380517504
# Variables: ('Holiday', 'Time_Segment', 'Season', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8051750380517504
# Variables: ('Holiday', 'Time_Segment', 'PPT', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.7975646879756468
# Variables: ('Holiday', 'Time_Segment', 'PPT', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Time_Segment', 'PPT', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.7990867579908676
# Variables: ('Holiday', 'Time_Segment', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Time_Segment', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.802130898021309
# Variables: ('Holiday', 'Time_Segment', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8112633181126332
# Variables: ('Holiday', 'VVM10', 'Season', 'PPT')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.5799086757990868
# Variables: ('Holiday', 'VVM10', 'Season', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'VVM10', 'Season', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'VVM10', 'Season', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5829528158295282
# Variables: ('Holiday', 'VVM10', 'PPT', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5707762557077626
# Variables: ('Holiday', 'VVM10', 'PPT', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5707762557077626
# Variables: ('Holiday', 'VVM10', 'PPT', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.5707762557077626
# Variables: ('Holiday', 'VVM10', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.589041095890411
# Variables: ('Holiday', 'VVM10', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5722983257229832
# Variables: ('Holiday', 'VVM10', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5859969558599696
# Variables: ('Holiday', 'Season', 'PPT', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5829528158295282
# Variables: ('Holiday', 'Season', 'PPT', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5707762557077626
# Variables: ('Holiday', 'Season', 'PPT', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5920852359208524
# Variables: ('Holiday', 'Season', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.5768645357686454
# Variables: ('Holiday', 'Season', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5966514459665144
# Variables: ('Holiday', 'Season', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5981735159817352
# Variables: ('Holiday', 'PPT', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5570776255707762
# Variables: ('Holiday', 'PPT', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.5799086757990868
# Variables: ('Holiday', 'PPT', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5707762557077626
# Variables: ('Holiday', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5799086757990868
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'Season')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.7853881278538812
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'PPT')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.7671232876712328
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'TM')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.7838660578386606
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'Week_day')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8006088280060882
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.7929984779299848
# Variables: ('Weekend Return', 'Time_Segment', 'Season', 'PPT')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.7884322678843226
# Variables: ('Weekend Return', 'Time_Segment', 'Season', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.7884322678843226
# Variables: ('Weekend Return', 'Time_Segment', 'Season', 'Week_day')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.7899543378995434
# Variables: ('Weekend Return', 'Time_Segment', 'Season', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.791476407914764
# Variables: ('Weekend Return', 'Time_Segment', 'PPT', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.7884322678843226
# Variables: ('Weekend Return', 'Time_Segment', 'PPT', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8097412480974124
# Variables: ('Weekend Return', 'Time_Segment', 'PPT', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.7975646879756468
# Variables: ('Weekend Return', 'Time_Segment', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8082191780821918
# Variables: ('Weekend Return', 'Time_Segment', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.7853881278538812
# Variables: ('Weekend Return', 'Time_Segment', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8097412480974124
# Variables: ('Weekend Return', 'VVM10', 'Season', 'PPT')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5312024353120244
# Variables: ('Weekend Return', 'VVM10', 'Season', 'TM')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5403348554033486
# Variables: ('Weekend Return', 'VVM10', 'Season', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5799086757990868
# Variables: ('Weekend Return', 'VVM10', 'Season', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5829528158295282
# Variables: ('Weekend Return', 'VVM10', 'PPT', 'TM')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5372907153729072
# Variables: ('Weekend Return', 'VVM10', 'PPT', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.578386605783866
# Variables: ('Weekend Return', 'VVM10', 'PPT', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5859969558599696
# Variables: ('Weekend Return', 'VVM10', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.589041095890411
# Variables: ('Weekend Return', 'VVM10', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.5753424657534246
# Variables: ('Weekend Return', 'VVM10', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5859969558599696
# Variables: ('Weekend Return', 'Season', 'PPT', 'TM')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.573820395738204
# Variables: ('Weekend Return', 'Season', 'PPT', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5829528158295282
# Variables: ('Weekend Return', 'Season', 'PPT', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.573820395738204
# Variables: ('Weekend Return', 'Season', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.5799086757990868
# Variables: ('Weekend Return', 'Season', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.5814307458143074
# Variables: ('Weekend Return', 'Season', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5951293759512938
# Variables: ('Weekend Return', 'PPT', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5677321156773212
# Variables: ('Weekend Return', 'PPT', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.5616438356164384
# Variables: ('Weekend Return', 'PPT', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5829528158295282
# Variables: ('Weekend Return', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5799086757990868
# Variables: ('Time_Segment', 'VVM10', 'Season', 'PPT')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.7595129375951294
# Variables: ('Time_Segment', 'VVM10', 'Season', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.7686453576864536
# Variables: ('Time_Segment', 'VVM10', 'Season', 'Week_day')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.7975646879756468
# Variables: ('Time_Segment', 'VVM10', 'Season', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.7792998477929984
# Variables: ('Time_Segment', 'VVM10', 'PPT', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.756468797564688
# Variables: ('Time_Segment', 'VVM10', 'PPT', 'Week_day')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.7945205479452054
# Variables: ('Time_Segment', 'VVM10', 'PPT', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.7625570776255708
# Variables: ('Time_Segment', 'VVM10', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.7960426179604262
# Variables: ('Time_Segment', 'VVM10', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.7792998477929984
# Variables: ('Time_Segment', 'VVM10', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8097412480974124
# Variables: ('Time_Segment', 'Season', 'PPT', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.7625570776255708
# Variables: ('Time_Segment', 'Season', 'PPT', 'Week_day')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.7747336377473364
# Variables: ('Time_Segment', 'Season', 'PPT', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.7792998477929984
# Variables: ('Time_Segment', 'Season', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8051750380517504
# Variables: ('Time_Segment', 'Season', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.7792998477929984
# Variables: ('Time_Segment', 'Season', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.7945205479452054
# Variables: ('Time_Segment', 'PPT', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8082191780821918
# Variables: ('Time_Segment', 'PPT', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.7777777777777778
# Variables: ('Time_Segment', 'PPT', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.8097412480974124
# Variables: ('Time_Segment', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8082191780821918
# Variables: ('VVM10', 'Season', 'PPT', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.4946727549467275
# Variables: ('VVM10', 'Season', 'PPT', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5829528158295282
# Variables: ('VVM10', 'Season', 'PPT', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5068493150684932
# Variables: ('VVM10', 'Season', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5799086757990868
# Variables: ('VVM10', 'Season', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5235920852359208
# Variables: ('VVM10', 'Season', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5829528158295282
# Variables: ('VVM10', 'PPT', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5707762557077626
# Variables: ('VVM10', 'PPT', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.5312024353120244
# Variables: ('VVM10', 'PPT', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.589041095890411
# Variables: ('VVM10', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.5768645357686454
# Variables: ('Season', 'PPT', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.5829528158295282
# Variables: ('Season', 'PPT', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.5403348554033486
# Variables: ('Season', 'PPT', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5951293759512938
# Variables: ('Season', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.5829528158295282
# Variables: ('PPT', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.589041095890411

# %%
# Imprimir los resultados con precisión mayor que 0.815
for combo, best_params, accuracy in results:
    if accuracy > 0.81:
        print("Variables:", combo)
        print("Best Parameters:", best_params)
        print("Accuracy:", accuracy)
# Out:
# Variables: ('Holiday', 'Time_Segment', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8112633181126332

# %%
accuracies = []

# Iterar sobre los resultados y extraer las accuracies
for combo, best_params, accuracy in results:
    accuracies.append(accuracy)

# Encontrar la precisión mínima
min_accuracy = min(accuracies)

# Imprimir la precisión mínima
print("Precisión mínima:", min_accuracy)
# Out:
# Precisión mínima: 0.4946727549467275

# %%
#Variables: ('VVM10', 'Season', 'PPT', 'TM')
#Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
#Accuracy: 0.4946727549467275
