# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn import tree
import pandas as pd
from sklearn import tree
from sklearn.model_selection import train_test_split
import numpy as np
from matplotlib import pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import itertools
from sklearn.preprocessing import LabelEncoder

def encoder(df, columns):
    mapeo = {'Yes': 1, 'No': 0}
    df['Holiday'] = df['Holiday'].map(mapeo)
    df['Weekend Return'] = df['Weekend Return'].map(mapeo)
    df = pd.get_dummies(df[columns], columns=columns)
    df = df.astype(float)
    return df

# Leer el dataset
df = pd.read_csv('dataset.csv')

# Definir todas las variables excepto la variable objetivo
variables = ['Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'PPT', 'TM', 'Week_day', 'Vacation_week']

# Generar todas las combinaciones posibles de 6 variables
combinations = list(itertools.combinations(variables, 7))

# Inicializar una lista para almacenar los resultados
results = []

# Iterar sobre cada combinación
for combo in combinations:
    # Hacer una copia del DataFrame original para cada combinación
    df_copy = df.copy()
    # Codificar solo las variables presentes en la combinación
    df_encoded = encoder(df_copy, list(combo))
    # Dividir el conjunto de datos en características (X) y objetivo (y)
    X = df_encoded
    y = df['Exceeds Threshold']
    split_index = int(len(df) * 0.85)
    X_train, X_test = X[:split_index], X[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    
    # Definir los hiperparámetros que deseas optimizar
    param_grid = {
        'max_depth': [5, 10, 15],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    }
    
    # Inicializar el modelo DecisionTreeClassifier
    model = DecisionTreeClassifier()
    
    # Inicializar GridSearchCV
    grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy')
    
    # Entrenar el modelo con Grid Search
    grid_search.fit(X_train, y_train)
    
    # Obtener la mejor combinación de hiperparámetros
    best_params = grid_search.best_params_
    
    # Crear el modelo con la mejor combinación de hiperparámetros
    best_model = DecisionTreeClassifier(**best_params)
    
    # Entrenar el mejor modelo
    best_model.fit(X_train, y_train)
    
    # Realizar predicciones
    y_pred = best_model.predict(X_test)
    
    # Calcular la precisión
    accuracy = accuracy_score(y_test, y_pred)
    
    # Agregar los resultados a la lista
    results.append((combo, best_params, accuracy))


# Imprimir los resultados
for combo, best_params, accuracy in results:
    print("Variables:", combo)
    print("Best Parameters:", best_params)
    print("Accuracy:", accuracy)
# Out:
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'PPT', 'TM')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.806697108066971
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'PPT', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.806697108066971
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'PPT', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.806697108066971
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.806697108066971
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.806697108066971
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.806697108066971
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'PPT', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'PPT', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'PPT', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8112633181126332
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8112633181126332
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'Season', 'PPT', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.8051750380517504
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'Season', 'PPT', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8051750380517504
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'Season', 'PPT', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.8051750380517504
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'Season', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8051750380517504
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.8082191780821918
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'Season', 'PPT', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.5829528158295282
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'Season', 'PPT', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.5768645357686454
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'Season', 'PPT', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.5799086757990868
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'Season', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.5814307458143074
# Variables: ('Holiday', 'Weekend Return', 'VVM10', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.5768645357686454
# Variables: ('Holiday', 'Weekend Return', 'Season', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.589041095890411
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'Season', 'PPT', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.806697108066971
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'Season', 'PPT', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.7990867579908676
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'Season', 'PPT', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.776255707762557
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'Season', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.806697108066971
# Variables: ('Holiday', 'Time_Segment', 'VVM10', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.8097412480974124
# Variables: ('Holiday', 'Time_Segment', 'Season', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.8051750380517504
# Variables: ('Holiday', 'VVM10', 'Season', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.5768645357686454
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'PPT', 'TM', 'Week_day')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.806697108066971
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'PPT', 'TM', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.7853881278538812
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'PPT', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.7960426179604262
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'Season', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8036529680365296
# Variables: ('Weekend Return', 'Time_Segment', 'VVM10', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8082191780821918
# Variables: ('Weekend Return', 'Time_Segment', 'Season', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.8051750380517504
# Variables: ('Weekend Return', 'VVM10', 'Season', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.5829528158295282
# Variables: ('Time_Segment', 'VVM10', 'Season', 'PPT', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.806697108066971

# %%
# Imprimir los resultados con precisión mayor que 0.815
for combo, best_params, accuracy in results:
    if accuracy > 0.81:
        print("Variables:", combo)
        print("Best Parameters:", best_params)
        print("Accuracy:", accuracy)
# Out:
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'PPT', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8112633181126332
# Variables: ('Holiday', 'Weekend Return', 'Time_Segment', 'VVM10', 'TM', 'Week_day', 'Vacation_week')
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8112633181126332
