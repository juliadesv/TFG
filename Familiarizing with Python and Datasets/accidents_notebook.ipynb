# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dataframe_accidents2022.csv')

# %%
df.tail(188)
# Out:
#      Numero_expedient  Codi_districte        Nom_districte  Codi_barri  \
# 7018  2022S007798                   2             Eixample           9
# 7019  2022S007800                   4            Les Corts          19
# 7020  2022S007802                   3       Sants-Montjuïc          14
# 7021  2022S007801                   4            Les Corts          19
# 7022  2022S007812                   2             Eixample           5
# ...               ...             ...                  ...         ...
# 7201  2023S000004                   6               Gràcia          28
# 7202  2022S008010                   5  Sarrià-Sant Gervasi          26
# 7203  2022S008011                   8           Nou Barris          48
# 7204  2022S008007                   8           Nou Barris          44
# 7205  2022S008009                   5  Sarrià-Sant Gervasi          26
#
#                            Nom_barri  Codi_carrer           Nom_carrer  \
# ...

# %%
import seaborn as sns

# %%
sns.factorplot(x='Estacio', data=df, kind='count').set_axis_labels('Estacio','Numero_accidents')
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='Franja_horaria', data=df, col='Ponts', kind='count',col_wrap=2).set_axis_labels('Franja_horaria','Ponts')
# Out:
# C:\Users\julsd\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
 pr=pd.read_csv('VICTIMES.csv')

# %%
pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9065 entries, 0 to 9064
# Data columns (total 29 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Numero_expedient                         9065 non-null   object
#  1   Codi_districte                           9065 non-null   int64
#  2   Nom_districte                            9065 non-null   object
#  3   Codi_barri                               9065 non-null   int64
#  4   Nom_barri                                9065 non-null   object
#  5   Codi_carrer                              9065 non-null   int64
#  6   Nom_carrer                               9065 non-null   object
#  7   Num_postal                               9065 non-null   object
#  8   Descripcio_dia_setmana                   9065 non-null   object
#  9   NK_ Any                                  9065 non-null   int64
# ...

# %%
pr['Number victims'] = pr['Numero_expedient'].apply(lambda x: pr['Numero_expedient'].value_counts(normalize=True))

print(pr)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number victims'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pr.drop(columns=['Latitud'], inplace=True)

# %%
pr.drop(columns=['Longitud'], inplace=True)

# %%
pr
# Out:
#      Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0     2022S000001                   2        Eixample           9
# 1     2022S000002                   2        Eixample           7
# 2     2022S000003                   2        Eixample           9
# 3     2022S000003                   2        Eixample           9
# 4     2022S000004                   7  Horta-Guinardó          33
# ...               ...             ...             ...         ...
# 9060  2022S008011                   8      Nou Barris          48
# 9061  2022S008012                   6          Gràcia          31
# 9062  2022S008013                   2        Eixample           8
# 9063  2023S000004                   6          Gràcia          28
# 9064  2023S000550                   2        Eixample           7
#
#                             Nom_barri  Codi_carrer           Nom_carrer  \
# 0      la Nova Esquerra de l'Eixample       110803              Entença
# ...

# %%
pr['Number victims'] = pr['Numero_expedient'].apply(lambda x: pr['Numero_expedient'].value_counts(normalize=True))

print(pr)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number victims'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pr
# Out:
#      Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0     2022S000001                   2        Eixample           9
# 1     2022S000002                   2        Eixample           7
# 2     2022S000003                   2        Eixample           9
# 3     2022S000003                   2        Eixample           9
# 4     2022S000004                   7  Horta-Guinardó          33
# ...               ...             ...             ...         ...
# 9060  2022S008011                   8      Nou Barris          48
# 9061  2022S008012                   6          Gràcia          31
# 9062  2022S008013                   2        Eixample           8
# 9063  2023S000004                   6          Gràcia          28
# 9064  2023S000550                   2        Eixample           7
#
#                             Nom_barri  Codi_carrer           Nom_carrer  \
# 0      la Nova Esquerra de l'Eixample       110803              Entença
# ...
